# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/adjprice.csv")

# %%
data.head()
# Out:
#        Date  0111145D US Equity  0202445Q US Equity  0203524D US Equity  \
# 0  19930907             13.2719             13.6829              8.4429
# 1  19930908             13.3263             13.5315              8.2147
# 2  19930909             13.7070             13.3800              8.7852
# 3  19930910             13.3807             13.4810              9.4127
# 4  19930911             13.3807             13.4810              9.4127
#
#    0226226D US Equity  0376152D US Equity  0440296D US Equity  \
# 0              8.1042              11.000             57.3245
# 1              7.9590              11.000             57.2096
# 2              8.0627              11.125             59.1625
# 3              8.0368              11.125             59.6220
# 4              8.0368              11.125             59.6220
#
#    0544749D US Equity  0574018D US Equity  0598884D US Equity  ...  \
# 0             17.8887              6.8315             28.1246  ...
# 1             17.8064              6.8315             27.5051  ...
# 2             17.6831              6.8315             27.7529  ...
# 3             17.6420              6.8773             27.5051  ...
# 4             17.6420              6.8773             27.5051  ...
#
#    YNR US Equity  YRCW US Equity  YUM US Equity  YUMC US Equity  \
# 0            NaN     144439.5121            NaN             NaN
# 1            NaN     143691.1208            NaN             NaN
# 2            NaN     143691.1208            NaN             NaN
# 3            NaN     145187.9033            NaN             NaN
# 4            NaN     145187.9033            NaN             NaN
#
#    ZBH US Equity  ZETHQ US Equity  ZION US Equity  ZRN US Equity  \
# 0            NaN            6.875          7.1675        30.7970
# 1            NaN            6.750          6.9766        30.0188
# 2            NaN            6.625          6.9554        30.0188
# 3            NaN            6.750          7.2099        29.6852
# 4            NaN            6.750          7.2099        29.6852
#
#    ZTS US Equity  ZTS-W US Equity
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
#
# [5 rows x 1200 columns]

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%Y%m%d')
data
# Out:
#            Date  0111145D US Equity  0202445Q US Equity  0203524D US Equity  \
# 0    1993-09-07             13.2719             13.6829              8.4429
# 1    1993-09-08             13.3263             13.5315              8.2147
# 2    1993-09-09             13.7070             13.3800              8.7852
# 3    1993-09-10             13.3807             13.4810              9.4127
# 4    1993-09-11             13.3807             13.4810              9.4127
# ...         ...                 ...                 ...                 ...
# 9454 2019-07-27                 NaN                 NaN                 NaN
# 9455 2019-07-28                 NaN                 NaN                 NaN
# 9456 2019-07-29                 NaN                 NaN                 NaN
# 9457 2019-07-30                 NaN                 NaN                 NaN
# 9458 2019-07-31                 NaN                 NaN                 NaN
#
#       0226226D US Equity  0376152D US Equity  0440296D US Equity  \
# 0                 8.1042              11.000             57.3245
# 1                 7.9590              11.000             57.2096
# 2                 8.0627              11.125             59.1625
# 3                 8.0368              11.125             59.6220
# 4                 8.0368              11.125             59.6220
# ...                  ...                 ...                 ...
# 9454                 NaN                 NaN                 NaN
# 9455                 NaN                 NaN                 NaN
# 9456                 NaN                 NaN                 NaN
# 9457                 NaN                 NaN                 NaN
# 9458                 NaN                 NaN                 NaN
#
#       0544749D US Equity  0574018D US Equity  0598884D US Equity  ...  \
# 0                17.8887              6.8315             28.1246  ...
# 1                17.8064              6.8315             27.5051  ...
# 2                17.6831              6.8315             27.7529  ...
# 3                17.6420              6.8773             27.5051  ...
# 4                17.6420              6.8773             27.5051  ...
# ...                  ...                 ...                 ...  ...
# 9454                 NaN                 NaN                 NaN  ...
# 9455                 NaN                 NaN                 NaN  ...
# 9456                 NaN                 NaN                 NaN  ...
# 9457                 NaN                 NaN                 NaN  ...
# 9458                 NaN                 NaN                 NaN  ...
#
#       YNR US Equity  YRCW US Equity  YUM US Equity  YUMC US Equity  \
# 0               NaN     144439.5121            NaN             NaN
# 1               NaN     143691.1208            NaN             NaN
# 2               NaN     143691.1208            NaN             NaN
# 3               NaN     145187.9033            NaN             NaN
# 4               NaN     145187.9033            NaN             NaN
# ...             ...             ...            ...             ...
# 9454            NaN          3.3500         114.02           45.31
# 9455            NaN          3.3500         114.02           45.31
# 9456            NaN          3.1800         114.10           45.43
# 9457            NaN          3.1800         113.24           44.00
# 9458            NaN          3.1800         113.24           44.00
#
#       ZBH US Equity  ZETHQ US Equity  ZION US Equity  ZRN US Equity  \
# 0               NaN            6.875          7.1675        30.7970
# 1               NaN            6.750          6.9766        30.0188
# 2               NaN            6.625          6.9554        30.0188
# 3               NaN            6.750          7.2099        29.6852
# 4               NaN            6.750          7.2099        29.6852
# ...             ...              ...             ...            ...
# 9454         134.50              NaN         45.1600            NaN
# 9455         134.50              NaN         45.1600            NaN
# 9456         134.53              NaN         44.6500            NaN
# 9457         136.67              NaN         45.4800            NaN
# 9458         136.67              NaN         45.4800            NaN
#
#       ZTS US Equity  ZTS-W US Equity
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# ...             ...              ...
# 9454         115.11              NaN
# 9455         115.11              NaN
# 9456         115.55              NaN
# 9457         115.79              NaN
# 9458         115.79              NaN
#
# [9459 rows x 1200 columns]

# %%
t_list = data.columns
tf_list = t_list[1:]

# %%
a_list =[]
for i in tf_list:
  a_list.append(i)
a_list
# Out:
# ['0111145D US Equity',
#  '0202445Q US Equity',
#  '0203524D US Equity',
#  '0226226D US Equity',
#  '0376152D US Equity',
#  '0440296D US Equity',
#  '0544749D US Equity',
#  '0574018D US Equity',
#  '0598884D US Equity',
#  '0772031D US Equity',
#  '0820143D US Equity',
#  '0848680D US Equity',
#  '0867887D US Equity',
#  '0872237D US Equity',
#  '0910150D US Equity',
#  '0943554D US Equity',
#  '0948669D US Equity',
#  '0961514D US Equity',
#  '0964591D US Equity',
#  '1005945D US Equity',
#  '1013207D US Equity',
#  '1028411Q US Equity',
#  '1040983D US Equity',
#  '1051665D US Equity',
#  '1073675D US Equity',
#  '1086832D US Equity',
#  '1166Q US Equity',
#  '1199Q US Equity',
#  '1237Q US Equity',
#  '1255173D US Equity',
#  '1255177D US Equity',
#  '1255459D US Equity',
#  '126784Q US Equity',
#  '1270Q US Equity',
#  '1280712D US Equity',
#  '1281683D US Equity',
#  '1284849D US Equity',
#  '1288453D US Equity',
#  '1288652D US Equity',
#  '1291Q US Equity',
#  '1293405D US Equity',
#  '1297Q US Equity',
#  '1312089D US Equity',
#  '1317355D US Equity',
#  '1327Q US Equity',
#  '134618Q US Equity',
#  '1356Q US Equity',
#  '1377Q US Equity',
#  '140402Q US Equity',
#  '1423Q US Equity',
#  '1431816D US Equity',
#  '1436513D US Equity',
#  '1448062D US Equity',
#  '1455Q US Equity',
#  '1456Q US Equity',
#  '1463Q US Equity',
#  '1500785D US Equity',
#  '1511Q US Equity',
#  '1513Q US Equity',
#  '1518855D US Equity',
#  '1519128D US Equity',
#  '1520415D US Equity',
#  '1524867D US Equity',
#  '1528159D US Equity',
#  '1530Q US Equity',
#  '1539547D US Equity',
#  '1539941D US Equity',
#  '1541931D US Equity',
#  '1558530D US Equity',
#  '1566019D US Equity',
#  '1567Q US Equity',
#  '1581Q US Equity',
#  '1618Q US Equity',
#  '162007Q US Equity',
#  '1621582D US Equity',
#  '1624Q US Equity',
#  '1627457D US Equity',
#  '1649858D US Equity',
#  '1654539D US Equity',
#  '1671Q US Equity',
#  '1680Q US Equity',
#  '1719Q US Equity',
#  '1802Q US Equity',
#  '183291Q US Equity',
#  '1856Q US Equity',
#  '1953Q US Equity',
#  '1958Q US Equity',
#  '1974Q US Equity',
#  '2009Q US Equity',
#  '202550Q US Equity',
#  '2036Q US Equity',
#  '204923Q US Equity',
#  '2106Q US Equity',
#  '210811Q US Equity',
#  '210967Q US Equity',
#  '2168Q US Equity',
#  '2196Q US Equity',
#  '2200Q US Equity',
#  '2206Q US Equity',
#  '2218Q US Equity',
#  '2223Q US Equity',
#  '222435Q US Equity',
#  '2245Q US Equity',
#  '2251Q US Equity',
#  '2254Q US Equity',
#  '2269312Q US Equity',
#  '2282655Q US Equity',
#  '2284Q US Equity',
#  '228510Q US Equity',
#  '2288005Q US Equity',
#  '2292198Q US Equity',
#  '2307532Q US Equity',
#  '231079Q US Equity',
#  '231330Q US Equity',
#  '2340361Q US Equity',
#  '236555Q US Equity',
#  '2428Q US Equity',
#  '244630Q US Equity',
#  '2500Q US Equity',
#  '253647Q US Equity',
#  '2576Q US Equity',
#  '2603Q US Equity',
#  '263179Q US Equity',
#  '2638Q US Equity',
#  '2641504Q US Equity',
#  '2650Q US Equity',
#  '2676187Q US Equity',
#  '2691Q US Equity',
#  '2727195Q US Equity',
#  '2731112Q US Equity',
#  '2745Q US Equity',
#  '2746Q US Equity',
#  '2755Q US Equity',
#  '2770014Q US Equity',
#  '2784Q US Equity',
#  '279776Q US Equity',
#  '2822069Q US Equity',
#  '285939Q US Equity',
#  '291784Q US Equity',
#  '2942331Q US Equity',
#  '2953349Q US Equity',
#  '2964Q US Equity',
#  '2968900Q US Equity',
#  '2972Q US Equity',
#  '297504Q US Equity',
#  '2987536Q US Equity',
#  '2987Q US Equity',
#  '2999130Q US Equity',
#  '300583Q US Equity',
#  '301710Q US Equity',
#  '3022239Q US Equity',
#  '3026360Q US Equity',
#  '3029830Q US Equity',
#  '304024Q US Equity',
#  '3054Q US Equity',
#  '3075558Q US Equity',
#  '3080867Q US Equity',
#  '3133754Q US Equity',
#  '3147596Q US Equity',
#  '3147Q US Equity',
#  '3153670Q US Equity',
#  '316419Q US Equity',
#  '3179Q US Equity',
#  '3253Q US Equity',
#  '3277Q US Equity',
#  '3286728Q US Equity',
#  '329556Q US Equity',
#  '3301Q US Equity',
#  '3346Q US Equity',
#  '334702Q US Equity',
#  '3362726Q US Equity',
#  '3393199Q US Equity',
#  '3403545Q US Equity',
#  '3414924Q US Equity',
#  '3423152Q US Equity',
#  '3459Q US Equity',
#  '3517233Q US Equity',
#  '3520842Q US Equity',
#  '3546Q US Equity',
#  '355488Q US Equity',
#  '3605818Q US Equity',
#  '3619382Q US Equity',
#  '3621240Q US Equity',
#  '363096Q US Equity',
#  '3691661Q US Equity',
#  '3692470Q US Equity',
#  '370506Q US Equity',
#  '375573Q US Equity',
#  '3891289Q US Equity',
#  '390297Q US Equity',
#  '399463Q US Equity',
#  '41018Q US Equity',
#  '45200Q US Equity',
#  '45861Q US Equity',
#  '4621824Q US Equity',
#  '502466Q US Equity',
#  '504369Q US Equity',
#  '519239Q US Equity',
#  '54279Q US Equity',
#  '544791Q US Equity',
#  '548227Q US Equity',
#  '571300Q US Equity',
#  '605018Q US Equity',
#  '605555Q US Equity',
#  '611647Q US Equity',
#  '62553Q US Equity',
#  '653707Q US Equity',
#  '667517Q US Equity',
#  '677004Q US Equity',
#  '680884Q US Equity',
#  '68335Q US Equity',
#  '693365Q US Equity',
#  '69895Q US Equity',
#  '723588Q US Equity',
#  '739306Q US Equity',
#  '748957Q US Equity',
#  '764144Q US Equity',
#  '8206908Q US Equity',
#  '8214761Q US Equity',
#  '827663Q US Equity',
#  '8277831Q US Equity',
#  '8375930Q US Equity',
#  '8394653Q US Equity',
#  '841273Q US Equity',
#  '89236Q US Equity',
#  '896661Q US Equity',
#  '90457Q US Equity',
#  '929530Q US Equity',
#  '93916Q US Equity',
#  '945852Q US Equity',
#  '950967Q US Equity',
#  '968734Q US Equity',
#  '987200Q US Equity',
#  '9876544D US Equity',
#  '9876549D US Equity',
#  '9876566D US Equity',
#  'A US Equity',
#  'AA US Equity',
#  'AAL US Equity',
#  'AALEA US Equity',
#  'AAMRQ US Equity',
#  'AAP US Equity',
#  'AAPL US Equity',
#  'ABBV US Equity',
#  'ABC US Equity',
#  'ABKFQ US Equity',
#  'ABMD US Equity',
#  'ABT US Equity',
#  'ABX US Equity',
#  'ACAS US Equity',
#  'ACKH US Equity',
#  'ACN US Equity',
#  'ADBE US Equity',
#  'ADCT US Equity',
#  'ADI US Equity',
#  'ADM US Equity',
#  'ADNT US Equity',
#  'ADP US Equity',
#  'ADS US Equity',
#  'ADSK US Equity',
#  'AEE US Equity',
#  'AEP US Equity',
#  'AES US Equity',
#  'AET US Equity',
#  'AFL US Equity',
#  'AFS US Equity',
#  'AGN US Equity',
#  'AIG US Equity',
#  'AIV US Equity',
#  'AIZ US Equity',
#  'AJG US Equity',
#  'AKAM US Equity',
#  'AKS US Equity',
#  'ALB US Equity',
#  'ALGN US Equity',
#  'ALK US Equity',
#  'ALL US Equity',
#  'ALLE US Equity',
#  'ALXN US Equity',
#  'AMAT US Equity',
#  'AMCC US Equity',
#  'AMCR US Equity',
#  'AMD US Equity',
#  'AME US Equity',
#  'AMG US Equity',
#  'AMGN US Equity',
#  'AMP US Equity',
#  'AMT US Equity',
#  'AMZN US Equity',
#  'AN US Equity',
#  'ANDV US Equity',
#  'ANDW US Equity',
#  'ANET US Equity',
#  'ANF US Equity',
#  'ANRZQ US Equity',
#  'ANSS US Equity',
#  'ANTM US Equity',
#  'AON US Equity',
#  'AOS US Equity',
#  'APA US Equity',
#  'APC US Equity',
#  'APD US Equity',
#  'APH US Equity',
#  'APOL US Equity',
#  'APTV US Equity',
#  'APY US Equity',
#  'ARB US Equity',
#  'ARE US Equity',
#  'ARG US Equity',
#  'ARNC US Equity',
#  'AS US Equity',
#  'ASH US Equity',
#  'ASIX US Equity',
#  'ATGE US Equity',
#  'ATI US Equity',
#  'ATO US Equity',
#  'ATVI US Equity',
#  'AVATQ US Equity',
#  'AVB US Equity',
#  'AVGO US Equity',
#  'AVP US Equity',
#  'AVY US Equity',
#  'AW US Equity',
#  'AWE US Equity',
#  'AWK US Equity',
#  'AXP US Equity',
#  'AYE US Equity',
#  'AYI US Equity',
#  'AZA US Equity',
#  'AZO US Equity',
#  'BA US Equity',
#  'BAC US Equity',
#  'BAX US Equity',
#  'BBBY US Equity',
#  'BBT US Equity',
#  'BBY US Equity',
#  'BC US Equity',
#  'BCO US Equity',
#  'BCR US Equity',
#  'BDK US Equity',
#  'BDX US Equity',
#  'BEAM US Equity',
#  'BEN US Equity',
#  'BF/B US Equity',
#  'BGEN US Equity',
#  'BGG US Equity',
#  'BHF US Equity',
#  'BHGE US Equity',
#  'BHI US Equity',
#  'BHMSQ US Equity',
#  'BIG US Equity',
#  'BIIB US Equity',
#  'BIVV US Equity',
#  'BK US Equity',
#  'BKB US Equity',
#  'BKNG US Equity',
#  'BLK US Equity',
#  'BLL US Equity',
#  'BLS US Equity',
#  'BLY US Equity',
#  'BMC US Equity',
#  'BMG US Equity',
#  'BMS US Equity',
#  'BMY US Equity',
#  'BNI US Equity',
#  'BOL US Equity',
#  'BR US Equity',
#  'BRCM US Equity',
#  'BRK/B US Equity',
#  'BRL US Equity',
#  'BSET US Equity',
#  'BSX US Equity',
#  'BTUUQ US Equity',
#  'BVSN US Equity',
#  'BWA US Equity',
#  'BXLT US Equity',
#  'BXP US Equity',
#  'C US Equity',
#  'CA US Equity',
#  'CAG US Equity',
#  'CAH US Equity',
#  'CAL US Equity',
#  'CAM US Equity',
#  'CAR US Equity',
#  'CARS US Equity',
#  'CAT US Equity',
#  'CB US Equity',
#  'CBE US Equity',
#  'CBOE US Equity',
#  'CBRE US Equity',
#  'CBS US Equity',
#  'CCI US Equity',
#  'CCK US Equity',
#  'CCL US Equity',
#  'CCTYQ US Equity',
#  'CDNS US Equity',
#  'CE US Equity',
#  'CEG US Equity',
#  'CELG US Equity',
#  'CEPH US Equity',
#  'CERN US Equity',
#  'CF US Equity',
#  'CFC US Equity',
#  'CFG US Equity',
#  'CFN US Equity',
#  'CGP US Equity',
#  'CHD US Equity',
#  'CHIR US Equity',
#  'CHK US Equity',
#  'CHRW US Equity',
#  'CHTR US Equity',
#  'CI US Equity',
#  'CIEN US Equity',
#  'CIN US Equity',
#  'CINF US Equity',
#  'CINL US Equity',
#  'CITGQ US Equity',
#  'CKL US Equity',
#  'CL US Equity',
#  'CLF US Equity',
#  'CLX US Equity',
#  'CMA US Equity',
#  'CMCSA US Equity',
#  'CMCSK US Equity',
#  'CME US Equity',
#  'CMG US Equity',
#  'CMI US Equity',
#  'CMS US Equity',
#  'CMVT US Equity',
#  'CMX US Equity',
#  'CNA US Equity',
#  'CNC US Equity',
#  'CNCEQ US Equity',
#  'CNDT US Equity',
#  'CNP US Equity',
#  'CNRG US Equity',
#  'CNW US Equity',
#  'CNX US Equity',
#  'COC US Equity',
#  'COF US Equity',
#  'COG US Equity',
#  'COL US Equity',
#  'COMS US Equity',
#  'COO US Equity',
#  'COP US Equity',
#  'COST US Equity',
#  'COTY US Equity',
#  'COV US Equity',
#  'CPB US Equity',
#  'CPGX US Equity',
#  'CPNLQ US Equity',
#  'CPRI US Equity',
#  'CPRT US Equity',
#  'CR US Equity',
#  'CRM US Equity',
#  'CSC US Equity',
#  'CSCO US Equity',
#  'CSRA US Equity',
#  'CSX US Equity',
#  'CTAS US Equity',
#  'CTB US Equity',
#  'CTL US Equity',
#  'CTSH US Equity',
#  'CTVA US Equity',
#  'CTXS US Equity',
#  'CVC US Equity',
#  'CVET US Equity',
#  'CVG US Equity',
#  'CVGYQ US Equity',
#  'CVH US Equity',
#  'CVS US Equity',
#  'CVX US Equity',
#  'CXO US Equity',
#  'D US Equity',
#  'DAL US Equity',
#  'DALRQ US Equity',
#  'DCNAQ US Equity',
#  'DD US Equity',
#  'DDS US Equity',
#  'DE US Equity',
#  'DEC US Equity',
#  'DELL US Equity',
#  'DF US Equity',
#  'DFS US Equity',
#  'DG US Equity',
#  'DGX US Equity',
#  'DHI US Equity',
#  'DHR US Equity',
#  'DIS US Equity',
#  'DISCA US Equity',
#  'DISCK US Equity',
#  'DISH US Equity',
#  'DJ US Equity',
#  'DLPH US Equity',
#  'DLR US Equity',
#  'DLTR US Equity',
#  'DLX US Equity',
#  'DNB US Equity',
#  'DNR US Equity',
#  'DO US Equity',
#  'DOV US Equity',
#  'DOW US Equity',
#  'DPHIQ US Equity',
#  'DRE US Equity',
#  'DRI US Equity',
#  'DTE US Equity',
#  'DUK US Equity',
#  'DVA US Equity',
#  'DVMT US Equity',
#  'DVN US Equity',
#  'DWDP US Equity',
#  'DXC US Equity',
#  'DYNIQ US Equity',
#  'EA US Equity',
#  'EBAY US Equity',
#  'ECL US Equity',
#  'ECO US Equity',
#  'ED US Equity',
#  'EFX US Equity',
#  'EHC US Equity',
#  'EIX US Equity',
#  'EKDKQ US Equity',
#  'EL US Equity',
#  'EMC US Equity',
#  'EMN US Equity',
#  'EMR US Equity',
#  'ENDP US Equity',
#  'ENRNQ US Equity',
#  'EOG US Equity',
#  'EOP US Equity',
#  'EP US Equity',
#  'EQIX US Equity',
#  'EQR US Equity',
#  'EQT US Equity',
#  'ES US Equity',
#  'ESRX US Equity',
#  'ESS US Equity',
#  'ESV US Equity',
#  'ETFC US Equity',
#  'ETN US Equity',
#  'ETR US Equity',
#  'ETS US Equity',
#  'EVHC US Equity',
#  'EVRG US Equity',
#  'EW US Equity',
#  'EXC US Equity',
#  'EXPD US Equity',
#  'EXPE US Equity',
#  'EXR US Equity',
#  'F US Equity',
#  'FANG US Equity',
#  'FAST US Equity',
#  'FB US Equity',
#  'FBF US Equity',
#  'FBHS US Equity',
#  'FBO US Equity',
#  'FCPT US Equity',
#  'FCX US Equity',
#  'FDO US Equity',
#  'FDX US Equity',
#  'FE US Equity',
#  'FFB US Equity',
#  'FFIV US Equity',
#  'FHN US Equity',
#  'FII US Equity',
#  'FIS US Equity',
#  'FISV US Equity',
#  'FITB US Equity',
#  'FJ US Equity',
#  'FJCC US Equity',
#  'FL US Equity',
#  'FLIR US Equity',
#  'FLMIQ US Equity',
#  'FLR US Equity',
#  'FLS US Equity',
#  'FLT US Equity',
#  'FLTWQ US Equity',
#  'FMC US Equity',
#  'FMCC US Equity',
#  'FNMA US Equity',
#  'FOSL US Equity',
#  'FOX US Equity',
#  'FOXA US Equity',
#  'FPC US Equity',
#  'FRC US Equity',
#  'FRT US Equity',
#  'FRX US Equity',
#  'FSH US Equity',
#  'FSL/B US Equity',
#  'FSLR US Equity',
#  'FTI US Equity',
#  'FTLAQ US Equity',
#  'FTNT US Equity',
#  'FTR US Equity',
#  'FTV US Equity',
#  'FWLT US Equity',
#  'GAPTQ US Equity',
#  'GAS US Equity',
#  'GBLXQ US Equity',
#  'GCO US Equity',
#  'GD US Equity',
#  'GDT US Equity',
#  'GDW US Equity',
#  'GE US Equity',
#  'GENZ US Equity',
#  'GFS/A US Equity',
#  'GGP US Equity',
#  'GHC US Equity',
#  'GIDL US Equity',
#  'GILD US Equity',
#  'GIS US Equity',
#  'GLW US Equity',
#  'GM US Equity',
#  'GMCR US Equity',
#  'GME US Equity',
#  'GNW US Equity',
#  'GOOG US Equity',
#  'GOOGL US Equity',
#  'GOSHA US Equity',
#  'GP US Equity',
#  'GPC US Equity',
#  'GPN US Equity',
#  'GPS US Equity',
#  'GPUI US Equity',
#  'GQ US Equity',
#  'GR US Equity',
#  'GRA US Equity',
#  'GRMN US Equity',
#  'GS US Equity',
#  'GT US Equity',
#  'GTGOF US Equity',
#  'GTW US Equity',
#  'GTX US Equity',
#  'GWW US Equity',
#  'HAL US Equity',
#  'HAR US Equity',
#  'HAS US Equity',
#  'HBAN US Equity',
#  'HBI US Equity',
#  'HCA US Equity',
#  'HCBK US Equity',
#  'HCP US Equity',
#  'HCR US Equity',
#  'HD US Equity',
#  'HDLM US Equity',
#  'HES US Equity',
#  'HET US Equity',
#  'HFC US Equity',
#  'HFS US Equity',
#  'HIG US Equity',
#  'HII US Equity',
#  'HLT US Equity',
#  'HM US Equity',
#  'HMA US Equity',
#  'HNZ US Equity',
#  'HOG US Equity',
#  'HOLX US Equity',
#  'HON US Equity',
#  'HOT US Equity',
#  'HP US Equity',
#  'HPC US Equity',
#  'HPE US Equity',
#  'HPQ US Equity',
#  'HRB US Equity',
#  'HRL US Equity',
#  'HRS US Equity',
#  'HRZIQ US Equity',
#  'HSH US Equity',
#  'HSIC US Equity',
#  'HSP US Equity',
#  'HST US Equity',
#  'HSY US Equity',
#  'HTMXQ US Equity',
#  'HUM US Equity',
#  'IAC US Equity',
#  'IBM US Equity',
#  'ICE US Equity',
#  'IDXX US Equity',
#  'IFF US Equity',
#  'IILGV US Equity',
#  'IKN US Equity',
#  'ILMN US Equity',
#  'IMNX US Equity',
#  'INCLF US Equity',
#  'INCY US Equity',
#  'INFO US Equity',
#  'INTC US Equity',
#  'INTU US Equity',
#  'IP US Equity',
#  'IPG US Equity',
#  'IPGP US Equity',
#  'IQV US Equity',
#  'IR US Equity',
#  'IRM US Equity',
#  'ISRG US Equity',
#  'IT US Equity',
#  'ITT US Equity',
#  'ITW US Equity',
#  'IVZ US Equity',
#  'JAVA US Equity',
#  'JBGS US Equity',
#  'JBHT US Equity',
#  'JBL US Equity',
#  'JCI US Equity',
#  'JCP US Equity',
#  'JEC US Equity',
#  'JEF US Equity',
#  'JH US Equity',
#  'JHF US Equity',
#  'JKHY US Equity',
#  'JNJ US Equity',
#  'JNPR US Equity',
#  'JNS US Equity',
#  'JNY US Equity',
#  'JOSEA US Equity',
#  'JOY US Equity',
#  'JPM US Equity',
#  'JWN US Equity',
#  'JWPI US Equity',
#  'K US Equity',
#  'KATE US Equity',
#  'KBH US Equity',
#  'KDP US Equity',
#  'KEY US Equity',
#  'KEYS US Equity',
#  'KG US Equity',
#  'KHC US Equity',
#  'KIM US Equity',
#  'KLAC US Equity',
#  'KMB US Equity',
#  'KMI US Equity',
#  'KMRTQ US Equity',
#  'KMX US Equity',
#  'KO US Equity',
#  'KORS US Equity',
#  'KR US Equity',
#  'KRB US Equity',
#  'KRFT US Equity',
#  'KRI US Equity',
#  'KSE US Equity',
#  'KSS US Equity',
#  'KSU US Equity',
#  'KTB US Equity',
#  'L US Equity',
#  'LB US Equity',
#  'LDG US Equity',
#  'LDOS US Equity',
#  'LDWIF US Equity',
#  'LEG US Equity',
#  'LEHMQ US Equity',
#  'LEN US Equity',
#  'LEN/B US Equity',
#  'LH US Equity',
#  'LHX US Equity',
#  'LIN US Equity',
#  'LK US Equity',
#  'LKQ US Equity',
#  'LLL US Equity',
#  'LLTC US Equity',
#  'LLX US Equity',
#  'LLY US Equity',
#  'LM US Equity',
#  'LMT US Equity',
#  'LNC US Equity',
#  'LNT US Equity',
#  'LO US Equity',
#  'LOW US Equity',
#  'LPX US Equity',
#  'LRCX US Equity',
#  'LU US Equity',
#  'LUB US Equity',
#  'LUV US Equity',
#  'LVLT US Equity',
#  'LW US Equity',
#  'LXK US Equity',
#  'LYB US Equity',
#  'M US Equity',
#  'MA US Equity',
#  'MAA US Equity',
#  'MAC US Equity',
#  'MAR US Equity',
#  'MAS US Equity',
#  'MAT US Equity',
#  'MBI US Equity',
#  'MCAWA US Equity',
#  'MCD US Equity',
#  'MCHP US Equity',
#  'MCK US Equity',
#  'MCO US Equity',
#  'MCWEQ US Equity',
#  'MDLZ US Equity',
#  'MDP US Equity',
#  'MDR US Equity',
#  'MDT US Equity',
#  'MEDI US Equity',
#  'MEE US Equity',
#  'MEL US Equity',
#  'MER US Equity',
#  'MERQ US Equity',
#  'MET US Equity',
#  'MFE US Equity',
#  'MGM US Equity',
#  'MHK US Equity',
#  'MHS US Equity',
#  'MI US Equity',
#  'MIRKQ US Equity',
#  'MJN US Equity',
#  'MJN-W US Equity',
#  'MKC US Equity',
#  'MKG US Equity',
#  'MKTX US Equity',
#  'MLM US Equity',
#  'MMC US Equity',
#  'MMM US Equity',
#  'MNK US Equity',
#  'MNST US Equity',
#  'MO US Equity',
#  'MOLX US Equity',
#  'MON US Equity',
#  'MOS US Equity',
#  'MPC US Equity',
#  'MRK US Equity',
#  'MRNKQ US Equity',
#  'MRO US Equity',
#  'MS US Equity',
#  'MSCI US Equity',
#  'MSFT US Equity',
#  'MSI US Equity',
#  'MTB US Equity',
#  'MTD US Equity',
#  'MTG US Equity',
#  'MTLQQ US Equity',
#  'MTW US Equity',
#  'MU US Equity',
#  'MUR US Equity',
#  'MWI US Equity',
#  'MWV US Equity',
#  'MWW US Equity',
#  'MXIM US Equity',
#  'MXS US Equity',
#  'MYL US Equity',
#  'MZIAQ US Equity',
#  'NAE US Equity',
#  'NAV US Equity',
#  'NAVI US Equity',
#  'NBL US Equity',
#  'NBR US Equity',
#  'NC US Equity',
#  'NCC US Equity',
#  'NCE US Equity',
#  'NCLH US Equity',
#  'NCR US Equity',
#  'NDAQ US Equity',
#  'NE US Equity',
#  'NEC US Equity',
#  'NEE US Equity',
#  'NEM US Equity',
#  'NEU US Equity',
#  'NFB US Equity',
#  'NFLX US Equity',
#  'NFX US Equity',
#  'NGH US Equity',
#  'NGVT US Equity',
#  'NI US Equity',
#  'NKE US Equity',
#  'NKTR US Equity',
#  'NL US Equity',
#  'NLSN US Equity',
#  'NMK US Equity',
#  'NOC US Equity',
#  'NOV US Equity',
#  'NOVL US Equity',
#  'NRG US Equity',
#  'NRTLQ US Equity',
#  'NSC US Equity',
#  'NTAP US Equity',
#  'NTRS US Equity',
#  'NUE US Equity',
#  'NVDA US Equity',
#  'NVT US Equity',
#  'NWL US Equity',
#  'NWS US Equity',
#  'NWSA US Equity',
#  'NXTL US Equity',
#  'NYT US Equity',
#  'NYX US Equity',
#  'O US Equity',
#  'OAT US Equity',
#  'ODP US Equity',
#  'OI US Equity',
#  'OK US Equity',
#  'OKE US Equity',
#  'OM US Equity',
#  'OMC US Equity',
#  'OMX US Equity',
#  'ORCL US Equity',
#  'ORLY US Equity',
#  'ORX US Equity',
#  'OWENQ US Equity',
#  'OXY US Equity',
#  'PALM US Equity',
#  'PAS US Equity',
#  'PAYX US Equity',
#  'PBCT US Equity',
#  'PBG US Equity',
#  'PBI US Equity',
#  'PCAR US Equity',
#  'PCG US Equity',
#  'PCH US Equity',
#  'PCL US Equity',
#  'PCP US Equity',
#  'PD US Equity',
#  'PDCO US Equity',
#  'PDG US Equity',
#  'PEG US Equity',
#  'PEP US Equity',
#  'PET US Equity',
#  'PETM US Equity',
#  'PFE US Equity',
#  'PFG US Equity',
#  'PG US Equity',
#  'PGL US Equity',
#  'PGR US Equity',
#  'PH US Equity',
#  'PHM US Equity',
#  'PKG US Equity',
#  'PKI US Equity',
#  'PLD US Equity',
#  'PLL US Equity',
#  'PM US Equity',
#  'PMCS US Equity',
#  'PNC US Equity',
#  'PNR US Equity',
#  'PNW US Equity',
#  'POM US Equity',
#  'PPG US Equity',
#  'PPL US Equity',
#  'PPW US Equity',
#  'PRDCQ US Equity',
#  'PRGO US Equity',
#  'PRU US Equity',
#  'PSA US Equity',
#  'PSX US Equity',
#  'PTC US Equity',
#  'PTV US Equity',
#  'PVH US Equity',
#  'PVN US Equity',
#  'PVT US Equity',
#  'PWER US Equity',
#  'PWR US Equity',
#  'PX US Equity',
#  'PXD US Equity',
#  'PYPL US Equity',
#  'QCOM US Equity',
#  'QCP US Equity',
#  'QEP US Equity',
#  'QLGC US Equity',
#  'QRVO US Equity',
#  'QTRN US Equity',
#  'R US Equity',
#  'RAD US Equity',
#  'RAI US Equity',
#  'RAL US Equity',
#  'RATL US Equity',
#  'RBD US Equity',
#  'RBK US Equity',
#  'RCL US Equity',
#  'RDC US Equity',
#  'RDPL US Equity',
#  'RE US Equity',
#  'REG US Equity',
#  'REGN US Equity',
#  'REZI US Equity',
#  'RF US Equity',
#  'RHDCQ US Equity',
#  'RHI US Equity',
#  'RHT US Equity',
#  'RIG US Equity',
#  'RJF US Equity',
#  'RL US Equity',
#  'RMD US Equity',
#  'RML US Equity',
#  'RNB US Equity',
#  'ROH US Equity',
#  'ROK US Equity',
#  'ROL US Equity',
#  'ROP US Equity',
#  'ROST US Equity',
#  'RRC US Equity',
#  'RRD US Equity',
#  'RSG US Equity',
#  'RSHCQ US Equity',
#  'RTN US Equity',
#  'RTN/B US Equity',
#  'RX US Equity',
#  'RYAN US Equity',
#  'RYC US Equity',
#  'SANM US Equity',
#  'SAPE US Equity',
#  'SBAC US Equity',
#  ...]

# %%
j = 0
for i in a_list:
  i = i[:-10]
  a_list[j] = i
  j+=1
a_list
# Out:
# ['0111145D',
#  '0202445Q',
#  '0203524D',
#  '0226226D',
#  '0376152D',
#  '0440296D',
#  '0544749D',
#  '0574018D',
#  '0598884D',
#  '0772031D',
#  '0820143D',
#  '0848680D',
#  '0867887D',
#  '0872237D',
#  '0910150D',
#  '0943554D',
#  '0948669D',
#  '0961514D',
#  '0964591D',
#  '1005945D',
#  '1013207D',
#  '1028411Q',
#  '1040983D',
#  '1051665D',
#  '1073675D',
#  '1086832D',
#  '1166Q',
#  '1199Q',
#  '1237Q',
#  '1255173D',
#  '1255177D',
#  '1255459D',
#  '126784Q',
#  '1270Q',
#  '1280712D',
#  '1281683D',
#  '1284849D',
#  '1288453D',
#  '1288652D',
#  '1291Q',
#  '1293405D',
#  '1297Q',
#  '1312089D',
#  '1317355D',
#  '1327Q',
#  '134618Q',
#  '1356Q',
#  '1377Q',
#  '140402Q',
#  '1423Q',
#  '1431816D',
#  '1436513D',
#  '1448062D',
#  '1455Q',
#  '1456Q',
#  '1463Q',
#  '1500785D',
#  '1511Q',
#  '1513Q',
#  '1518855D',
#  '1519128D',
#  '1520415D',
#  '1524867D',
#  '1528159D',
#  '1530Q',
#  '1539547D',
#  '1539941D',
#  '1541931D',
#  '1558530D',
#  '1566019D',
#  '1567Q',
#  '1581Q',
#  '1618Q',
#  '162007Q',
#  '1621582D',
#  '1624Q',
#  '1627457D',
#  '1649858D',
#  '1654539D',
#  '1671Q',
#  '1680Q',
#  '1719Q',
#  '1802Q',
#  '183291Q',
#  '1856Q',
#  '1953Q',
#  '1958Q',
#  '1974Q',
#  '2009Q',
#  '202550Q',
#  '2036Q',
#  '204923Q',
#  '2106Q',
#  '210811Q',
#  '210967Q',
#  '2168Q',
#  '2196Q',
#  '2200Q',
#  '2206Q',
#  '2218Q',
#  '2223Q',
#  '222435Q',
#  '2245Q',
#  '2251Q',
#  '2254Q',
#  '2269312Q',
#  '2282655Q',
#  '2284Q',
#  '228510Q',
#  '2288005Q',
#  '2292198Q',
#  '2307532Q',
#  '231079Q',
#  '231330Q',
#  '2340361Q',
#  '236555Q',
#  '2428Q',
#  '244630Q',
#  '2500Q',
#  '253647Q',
#  '2576Q',
#  '2603Q',
#  '263179Q',
#  '2638Q',
#  '2641504Q',
#  '2650Q',
#  '2676187Q',
#  '2691Q',
#  '2727195Q',
#  '2731112Q',
#  '2745Q',
#  '2746Q',
#  '2755Q',
#  '2770014Q',
#  '2784Q',
#  '279776Q',
#  '2822069Q',
#  '285939Q',
#  '291784Q',
#  '2942331Q',
#  '2953349Q',
#  '2964Q',
#  '2968900Q',
#  '2972Q',
#  '297504Q',
#  '2987536Q',
#  '2987Q',
#  '2999130Q',
#  '300583Q',
#  '301710Q',
#  '3022239Q',
#  '3026360Q',
#  '3029830Q',
#  '304024Q',
#  '3054Q',
#  '3075558Q',
#  '3080867Q',
#  '3133754Q',
#  '3147596Q',
#  '3147Q',
#  '3153670Q',
#  '316419Q',
#  '3179Q',
#  '3253Q',
#  '3277Q',
#  '3286728Q',
#  '329556Q',
#  '3301Q',
#  '3346Q',
#  '334702Q',
#  '3362726Q',
#  '3393199Q',
#  '3403545Q',
#  '3414924Q',
#  '3423152Q',
#  '3459Q',
#  '3517233Q',
#  '3520842Q',
#  '3546Q',
#  '355488Q',
#  '3605818Q',
#  '3619382Q',
#  '3621240Q',
#  '363096Q',
#  '3691661Q',
#  '3692470Q',
#  '370506Q',
#  '375573Q',
#  '3891289Q',
#  '390297Q',
#  '399463Q',
#  '41018Q',
#  '45200Q',
#  '45861Q',
#  '4621824Q',
#  '502466Q',
#  '504369Q',
#  '519239Q',
#  '54279Q',
#  '544791Q',
#  '548227Q',
#  '571300Q',
#  '605018Q',
#  '605555Q',
#  '611647Q',
#  '62553Q',
#  '653707Q',
#  '667517Q',
#  '677004Q',
#  '680884Q',
#  '68335Q',
#  '693365Q',
#  '69895Q',
#  '723588Q',
#  '739306Q',
#  '748957Q',
#  '764144Q',
#  '8206908Q',
#  '8214761Q',
#  '827663Q',
#  '8277831Q',
#  '8375930Q',
#  '8394653Q',
#  '841273Q',
#  '89236Q',
#  '896661Q',
#  '90457Q',
#  '929530Q',
#  '93916Q',
#  '945852Q',
#  '950967Q',
#  '968734Q',
#  '987200Q',
#  '9876544D',
#  '9876549D',
#  '9876566D',
#  'A',
#  'AA',
#  'AAL',
#  'AALEA',
#  'AAMRQ',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABC',
#  'ABKFQ',
#  'ABMD',
#  'ABT',
#  'ABX',
#  'ACAS',
#  'ACKH',
#  'ACN',
#  'ADBE',
#  'ADCT',
#  'ADI',
#  'ADM',
#  'ADNT',
#  'ADP',
#  'ADS',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AES',
#  'AET',
#  'AFL',
#  'AFS',
#  'AGN',
#  'AIG',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'AKS',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'ALXN',
#  'AMAT',
#  'AMCC',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMG',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'AN',
#  'ANDV',
#  'ANDW',
#  'ANET',
#  'ANF',
#  'ANRZQ',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'APC',
#  'APD',
#  'APH',
#  'APOL',
#  'APTV',
#  'APY',
#  'ARB',
#  'ARE',
#  'ARG',
#  'ARNC',
#  'AS',
#  'ASH',
#  'ASIX',
#  'ATGE',
#  'ATI',
#  'ATO',
#  'ATVI',
#  'AVATQ',
#  'AVB',
#  'AVGO',
#  'AVP',
#  'AVY',
#  'AW',
#  'AWE',
#  'AWK',
#  'AXP',
#  'AYE',
#  'AYI',
#  'AZA',
#  'AZO',
#  'BA',
#  'BAC',
#  'BAX',
#  'BBBY',
#  'BBT',
#  'BBY',
#  'BC',
#  'BCO',
#  'BCR',
#  'BDK',
#  'BDX',
#  'BEAM',
#  'BEN',
#  'BF/B',
#  'BGEN',
#  'BGG',
#  'BHF',
#  'BHGE',
#  'BHI',
#  'BHMSQ',
#  'BIG',
#  'BIIB',
#  'BIVV',
#  'BK',
#  'BKB',
#  'BKNG',
#  'BLK',
#  'BLL',
#  'BLS',
#  'BLY',
#  'BMC',
#  'BMG',
#  'BMS',
#  'BMY',
#  'BNI',
#  'BOL',
#  'BR',
#  'BRCM',
#  'BRK/B',
#  'BRL',
#  'BSET',
#  'BSX',
#  'BTUUQ',
#  'BVSN',
#  'BWA',
#  'BXLT',
#  'BXP',
#  'C',
#  'CA',
#  'CAG',
#  'CAH',
#  'CAL',
#  'CAM',
#  'CAR',
#  'CARS',
#  'CAT',
#  'CB',
#  'CBE',
#  'CBOE',
#  'CBRE',
#  'CBS',
#  'CCI',
#  'CCK',
#  'CCL',
#  'CCTYQ',
#  'CDNS',
#  'CE',
#  'CEG',
#  'CELG',
#  'CEPH',
#  'CERN',
#  'CF',
#  'CFC',
#  'CFG',
#  'CFN',
#  'CGP',
#  'CHD',
#  'CHIR',
#  'CHK',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CIEN',
#  'CIN',
#  'CINF',
#  'CINL',
#  'CITGQ',
#  'CKL',
#  'CL',
#  'CLF',
#  'CLX',
#  'CMA',
#  'CMCSA',
#  'CMCSK',
#  'CME',
#  'CMG',
#  'CMI',
#  'CMS',
#  'CMVT',
#  'CMX',
#  'CNA',
#  'CNC',
#  'CNCEQ',
#  'CNDT',
#  'CNP',
#  'CNRG',
#  'CNW',
#  'CNX',
#  'COC',
#  'COF',
#  'COG',
#  'COL',
#  'COMS',
#  'COO',
#  'COP',
#  'COST',
#  'COTY',
#  'COV',
#  'CPB',
#  'CPGX',
#  'CPNLQ',
#  'CPRI',
#  'CPRT',
#  'CR',
#  'CRM',
#  'CSC',
#  'CSCO',
#  'CSRA',
#  'CSX',
#  'CTAS',
#  'CTB',
#  'CTL',
#  'CTSH',
#  'CTVA',
#  'CTXS',
#  'CVC',
#  'CVET',
#  'CVG',
#  'CVGYQ',
#  'CVH',
#  'CVS',
#  'CVX',
#  'CXO',
#  'D',
#  'DAL',
#  'DALRQ',
#  'DCNAQ',
#  'DD',
#  'DDS',
#  'DE',
#  'DEC',
#  'DELL',
#  'DF',
#  'DFS',
#  'DG',
#  'DGX',
#  'DHI',
#  'DHR',
#  'DIS',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DJ',
#  'DLPH',
#  'DLR',
#  'DLTR',
#  'DLX',
#  'DNB',
#  'DNR',
#  'DO',
#  'DOV',
#  'DOW',
#  'DPHIQ',
#  'DRE',
#  'DRI',
#  'DTE',
#  'DUK',
#  'DVA',
#  'DVMT',
#  'DVN',
#  'DWDP',
#  'DXC',
#  'DYNIQ',
#  'EA',
#  'EBAY',
#  'ECL',
#  'ECO',
#  'ED',
#  'EFX',
#  'EHC',
#  'EIX',
#  'EKDKQ',
#  'EL',
#  'EMC',
#  'EMN',
#  'EMR',
#  'ENDP',
#  'ENRNQ',
#  'EOG',
#  'EOP',
#  'EP',
#  'EQIX',
#  'EQR',
#  'EQT',
#  'ES',
#  'ESRX',
#  'ESS',
#  'ESV',
#  'ETFC',
#  'ETN',
#  'ETR',
#  'ETS',
#  'EVHC',
#  'EVRG',
#  'EW',
#  'EXC',
#  'EXPD',
#  'EXPE',
#  'EXR',
#  'F',
#  'FANG',
#  'FAST',
#  'FB',
#  'FBF',
#  'FBHS',
#  'FBO',
#  'FCPT',
#  'FCX',
#  'FDO',
#  'FDX',
#  'FE',
#  'FFB',
#  'FFIV',
#  'FHN',
#  'FII',
#  'FIS',
#  'FISV',
#  'FITB',
#  'FJ',
#  'FJCC',
#  'FL',
#  'FLIR',
#  'FLMIQ',
#  'FLR',
#  'FLS',
#  'FLT',
#  'FLTWQ',
#  'FMC',
#  'FMCC',
#  'FNMA',
#  'FOSL',
#  'FOX',
#  'FOXA',
#  'FPC',
#  'FRC',
#  'FRT',
#  'FRX',
#  'FSH',
#  'FSL/B',
#  'FSLR',
#  'FTI',
#  'FTLAQ',
#  'FTNT',
#  'FTR',
#  'FTV',
#  'FWLT',
#  'GAPTQ',
#  'GAS',
#  'GBLXQ',
#  'GCO',
#  'GD',
#  'GDT',
#  'GDW',
#  'GE',
#  'GENZ',
#  'GFS/A',
#  'GGP',
#  'GHC',
#  'GIDL',
#  'GILD',
#  'GIS',
#  'GLW',
#  'GM',
#  'GMCR',
#  'GME',
#  'GNW',
#  'GOOG',
#  'GOOGL',
#  'GOSHA',
#  'GP',
#  'GPC',
#  'GPN',
#  'GPS',
#  'GPUI',
#  'GQ',
#  'GR',
#  'GRA',
#  'GRMN',
#  'GS',
#  'GT',
#  'GTGOF',
#  'GTW',
#  'GTX',
#  'GWW',
#  'HAL',
#  'HAR',
#  'HAS',
#  'HBAN',
#  'HBI',
#  'HCA',
#  'HCBK',
#  'HCP',
#  'HCR',
#  'HD',
#  'HDLM',
#  'HES',
#  'HET',
#  'HFC',
#  'HFS',
#  'HIG',
#  'HII',
#  'HLT',
#  'HM',
#  'HMA',
#  'HNZ',
#  'HOG',
#  'HOLX',
#  'HON',
#  'HOT',
#  'HP',
#  'HPC',
#  'HPE',
#  'HPQ',
#  'HRB',
#  'HRL',
#  'HRS',
#  'HRZIQ',
#  'HSH',
#  'HSIC',
#  'HSP',
#  'HST',
#  'HSY',
#  'HTMXQ',
#  'HUM',
#  'IAC',
#  'IBM',
#  'ICE',
#  'IDXX',
#  'IFF',
#  'IILGV',
#  'IKN',
#  'ILMN',
#  'IMNX',
#  'INCLF',
#  'INCY',
#  'INFO',
#  'INTC',
#  'INTU',
#  'IP',
#  'IPG',
#  'IPGP',
#  'IQV',
#  'IR',
#  'IRM',
#  'ISRG',
#  'IT',
#  'ITT',
#  'ITW',
#  'IVZ',
#  'JAVA',
#  'JBGS',
#  'JBHT',
#  'JBL',
#  'JCI',
#  'JCP',
#  'JEC',
#  'JEF',
#  'JH',
#  'JHF',
#  'JKHY',
#  'JNJ',
#  'JNPR',
#  'JNS',
#  'JNY',
#  'JOSEA',
#  'JOY',
#  'JPM',
#  'JWN',
#  'JWPI',
#  'K',
#  'KATE',
#  'KBH',
#  'KDP',
#  'KEY',
#  'KEYS',
#  'KG',
#  'KHC',
#  'KIM',
#  'KLAC',
#  'KMB',
#  'KMI',
#  'KMRTQ',
#  'KMX',
#  'KO',
#  'KORS',
#  'KR',
#  'KRB',
#  'KRFT',
#  'KRI',
#  'KSE',
#  'KSS',
#  'KSU',
#  'KTB',
#  'L',
#  'LB',
#  'LDG',
#  'LDOS',
#  'LDWIF',
#  'LEG',
#  'LEHMQ',
#  'LEN',
#  'LEN/B',
#  'LH',
#  'LHX',
#  'LIN',
#  'LK',
#  'LKQ',
#  'LLL',
#  'LLTC',
#  'LLX',
#  'LLY',
#  'LM',
#  'LMT',
#  'LNC',
#  'LNT',
#  'LO',
#  'LOW',
#  'LPX',
#  'LRCX',
#  'LU',
#  'LUB',
#  'LUV',
#  'LVLT',
#  'LW',
#  'LXK',
#  'LYB',
#  'M',
#  'MA',
#  'MAA',
#  'MAC',
#  'MAR',
#  'MAS',
#  'MAT',
#  'MBI',
#  'MCAWA',
#  'MCD',
#  'MCHP',
#  'MCK',
#  'MCO',
#  'MCWEQ',
#  'MDLZ',
#  'MDP',
#  'MDR',
#  'MDT',
#  'MEDI',
#  'MEE',
#  'MEL',
#  'MER',
#  'MERQ',
#  'MET',
#  'MFE',
#  'MGM',
#  'MHK',
#  'MHS',
#  'MI',
#  'MIRKQ',
#  'MJN',
#  'MJN-W',
#  'MKC',
#  'MKG',
#  'MKTX',
#  'MLM',
#  'MMC',
#  'MMM',
#  'MNK',
#  'MNST',
#  'MO',
#  'MOLX',
#  'MON',
#  'MOS',
#  'MPC',
#  'MRK',
#  'MRNKQ',
#  'MRO',
#  'MS',
#  'MSCI',
#  'MSFT',
#  'MSI',
#  'MTB',
#  'MTD',
#  'MTG',
#  'MTLQQ',
#  'MTW',
#  'MU',
#  'MUR',
#  'MWI',
#  'MWV',
#  'MWW',
#  'MXIM',
#  'MXS',
#  'MYL',
#  'MZIAQ',
#  'NAE',
#  'NAV',
#  'NAVI',
#  'NBL',
#  'NBR',
#  'NC',
#  'NCC',
#  'NCE',
#  'NCLH',
#  'NCR',
#  'NDAQ',
#  'NE',
#  'NEC',
#  'NEE',
#  'NEM',
#  'NEU',
#  'NFB',
#  'NFLX',
#  'NFX',
#  'NGH',
#  'NGVT',
#  'NI',
#  'NKE',
#  'NKTR',
#  'NL',
#  'NLSN',
#  'NMK',
#  'NOC',
#  'NOV',
#  'NOVL',
#  'NRG',
#  'NRTLQ',
#  'NSC',
#  'NTAP',
#  'NTRS',
#  'NUE',
#  'NVDA',
#  'NVT',
#  'NWL',
#  'NWS',
#  'NWSA',
#  'NXTL',
#  'NYT',
#  'NYX',
#  'O',
#  'OAT',
#  'ODP',
#  'OI',
#  'OK',
#  'OKE',
#  'OM',
#  'OMC',
#  'OMX',
#  'ORCL',
#  'ORLY',
#  'ORX',
#  'OWENQ',
#  'OXY',
#  'PALM',
#  'PAS',
#  'PAYX',
#  'PBCT',
#  'PBG',
#  'PBI',
#  'PCAR',
#  'PCG',
#  'PCH',
#  'PCL',
#  'PCP',
#  'PD',
#  'PDCO',
#  'PDG',
#  'PEG',
#  'PEP',
#  'PET',
#  'PETM',
#  'PFE',
#  'PFG',
#  'PG',
#  'PGL',
#  'PGR',
#  'PH',
#  'PHM',
#  'PKG',
#  'PKI',
#  'PLD',
#  'PLL',
#  'PM',
#  'PMCS',
#  'PNC',
#  'PNR',
#  'PNW',
#  'POM',
#  'PPG',
#  'PPL',
#  'PPW',
#  'PRDCQ',
#  'PRGO',
#  'PRU',
#  'PSA',
#  'PSX',
#  'PTC',
#  'PTV',
#  'PVH',
#  'PVN',
#  'PVT',
#  'PWER',
#  'PWR',
#  'PX',
#  'PXD',
#  'PYPL',
#  'QCOM',
#  'QCP',
#  'QEP',
#  'QLGC',
#  'QRVO',
#  'QTRN',
#  'R',
#  'RAD',
#  'RAI',
#  'RAL',
#  'RATL',
#  'RBD',
#  'RBK',
#  'RCL',
#  'RDC',
#  'RDPL',
#  'RE',
#  'REG',
#  'REGN',
#  'REZI',
#  'RF',
#  'RHDCQ',
#  'RHI',
#  'RHT',
#  'RIG',
#  'RJF',
#  'RL',
#  'RMD',
#  'RML',
#  'RNB',
#  'ROH',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RRC',
#  'RRD',
#  'RSG',
#  'RSHCQ',
#  'RTN',
#  'RTN/B',
#  'RX',
#  'RYAN',
#  'RYC',
#  'SANM',
#  'SAPE',
#  'SBAC',
#  ...]

# %%
a_list.insert(0, 'Date')
a_list
# Out:
# ['Date',
#  '0111145D',
#  '0202445Q',
#  '0203524D',
#  '0226226D',
#  '0376152D',
#  '0440296D',
#  '0544749D',
#  '0574018D',
#  '0598884D',
#  '0772031D',
#  '0820143D',
#  '0848680D',
#  '0867887D',
#  '0872237D',
#  '0910150D',
#  '0943554D',
#  '0948669D',
#  '0961514D',
#  '0964591D',
#  '1005945D',
#  '1013207D',
#  '1028411Q',
#  '1040983D',
#  '1051665D',
#  '1073675D',
#  '1086832D',
#  '1166Q',
#  '1199Q',
#  '1237Q',
#  '1255173D',
#  '1255177D',
#  '1255459D',
#  '126784Q',
#  '1270Q',
#  '1280712D',
#  '1281683D',
#  '1284849D',
#  '1288453D',
#  '1288652D',
#  '1291Q',
#  '1293405D',
#  '1297Q',
#  '1312089D',
#  '1317355D',
#  '1327Q',
#  '134618Q',
#  '1356Q',
#  '1377Q',
#  '140402Q',
#  '1423Q',
#  '1431816D',
#  '1436513D',
#  '1448062D',
#  '1455Q',
#  '1456Q',
#  '1463Q',
#  '1500785D',
#  '1511Q',
#  '1513Q',
#  '1518855D',
#  '1519128D',
#  '1520415D',
#  '1524867D',
#  '1528159D',
#  '1530Q',
#  '1539547D',
#  '1539941D',
#  '1541931D',
#  '1558530D',
#  '1566019D',
#  '1567Q',
#  '1581Q',
#  '1618Q',
#  '162007Q',
#  '1621582D',
#  '1624Q',
#  '1627457D',
#  '1649858D',
#  '1654539D',
#  '1671Q',
#  '1680Q',
#  '1719Q',
#  '1802Q',
#  '183291Q',
#  '1856Q',
#  '1953Q',
#  '1958Q',
#  '1974Q',
#  '2009Q',
#  '202550Q',
#  '2036Q',
#  '204923Q',
#  '2106Q',
#  '210811Q',
#  '210967Q',
#  '2168Q',
#  '2196Q',
#  '2200Q',
#  '2206Q',
#  '2218Q',
#  '2223Q',
#  '222435Q',
#  '2245Q',
#  '2251Q',
#  '2254Q',
#  '2269312Q',
#  '2282655Q',
#  '2284Q',
#  '228510Q',
#  '2288005Q',
#  '2292198Q',
#  '2307532Q',
#  '231079Q',
#  '231330Q',
#  '2340361Q',
#  '236555Q',
#  '2428Q',
#  '244630Q',
#  '2500Q',
#  '253647Q',
#  '2576Q',
#  '2603Q',
#  '263179Q',
#  '2638Q',
#  '2641504Q',
#  '2650Q',
#  '2676187Q',
#  '2691Q',
#  '2727195Q',
#  '2731112Q',
#  '2745Q',
#  '2746Q',
#  '2755Q',
#  '2770014Q',
#  '2784Q',
#  '279776Q',
#  '2822069Q',
#  '285939Q',
#  '291784Q',
#  '2942331Q',
#  '2953349Q',
#  '2964Q',
#  '2968900Q',
#  '2972Q',
#  '297504Q',
#  '2987536Q',
#  '2987Q',
#  '2999130Q',
#  '300583Q',
#  '301710Q',
#  '3022239Q',
#  '3026360Q',
#  '3029830Q',
#  '304024Q',
#  '3054Q',
#  '3075558Q',
#  '3080867Q',
#  '3133754Q',
#  '3147596Q',
#  '3147Q',
#  '3153670Q',
#  '316419Q',
#  '3179Q',
#  '3253Q',
#  '3277Q',
#  '3286728Q',
#  '329556Q',
#  '3301Q',
#  '3346Q',
#  '334702Q',
#  '3362726Q',
#  '3393199Q',
#  '3403545Q',
#  '3414924Q',
#  '3423152Q',
#  '3459Q',
#  '3517233Q',
#  '3520842Q',
#  '3546Q',
#  '355488Q',
#  '3605818Q',
#  '3619382Q',
#  '3621240Q',
#  '363096Q',
#  '3691661Q',
#  '3692470Q',
#  '370506Q',
#  '375573Q',
#  '3891289Q',
#  '390297Q',
#  '399463Q',
#  '41018Q',
#  '45200Q',
#  '45861Q',
#  '4621824Q',
#  '502466Q',
#  '504369Q',
#  '519239Q',
#  '54279Q',
#  '544791Q',
#  '548227Q',
#  '571300Q',
#  '605018Q',
#  '605555Q',
#  '611647Q',
#  '62553Q',
#  '653707Q',
#  '667517Q',
#  '677004Q',
#  '680884Q',
#  '68335Q',
#  '693365Q',
#  '69895Q',
#  '723588Q',
#  '739306Q',
#  '748957Q',
#  '764144Q',
#  '8206908Q',
#  '8214761Q',
#  '827663Q',
#  '8277831Q',
#  '8375930Q',
#  '8394653Q',
#  '841273Q',
#  '89236Q',
#  '896661Q',
#  '90457Q',
#  '929530Q',
#  '93916Q',
#  '945852Q',
#  '950967Q',
#  '968734Q',
#  '987200Q',
#  '9876544D',
#  '9876549D',
#  '9876566D',
#  'A',
#  'AA',
#  'AAL',
#  'AALEA',
#  'AAMRQ',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABC',
#  'ABKFQ',
#  'ABMD',
#  'ABT',
#  'ABX',
#  'ACAS',
#  'ACKH',
#  'ACN',
#  'ADBE',
#  'ADCT',
#  'ADI',
#  'ADM',
#  'ADNT',
#  'ADP',
#  'ADS',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AES',
#  'AET',
#  'AFL',
#  'AFS',
#  'AGN',
#  'AIG',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'AKS',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'ALXN',
#  'AMAT',
#  'AMCC',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMG',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'AN',
#  'ANDV',
#  'ANDW',
#  'ANET',
#  'ANF',
#  'ANRZQ',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'APC',
#  'APD',
#  'APH',
#  'APOL',
#  'APTV',
#  'APY',
#  'ARB',
#  'ARE',
#  'ARG',
#  'ARNC',
#  'AS',
#  'ASH',
#  'ASIX',
#  'ATGE',
#  'ATI',
#  'ATO',
#  'ATVI',
#  'AVATQ',
#  'AVB',
#  'AVGO',
#  'AVP',
#  'AVY',
#  'AW',
#  'AWE',
#  'AWK',
#  'AXP',
#  'AYE',
#  'AYI',
#  'AZA',
#  'AZO',
#  'BA',
#  'BAC',
#  'BAX',
#  'BBBY',
#  'BBT',
#  'BBY',
#  'BC',
#  'BCO',
#  'BCR',
#  'BDK',
#  'BDX',
#  'BEAM',
#  'BEN',
#  'BF/B',
#  'BGEN',
#  'BGG',
#  'BHF',
#  'BHGE',
#  'BHI',
#  'BHMSQ',
#  'BIG',
#  'BIIB',
#  'BIVV',
#  'BK',
#  'BKB',
#  'BKNG',
#  'BLK',
#  'BLL',
#  'BLS',
#  'BLY',
#  'BMC',
#  'BMG',
#  'BMS',
#  'BMY',
#  'BNI',
#  'BOL',
#  'BR',
#  'BRCM',
#  'BRK/B',
#  'BRL',
#  'BSET',
#  'BSX',
#  'BTUUQ',
#  'BVSN',
#  'BWA',
#  'BXLT',
#  'BXP',
#  'C',
#  'CA',
#  'CAG',
#  'CAH',
#  'CAL',
#  'CAM',
#  'CAR',
#  'CARS',
#  'CAT',
#  'CB',
#  'CBE',
#  'CBOE',
#  'CBRE',
#  'CBS',
#  'CCI',
#  'CCK',
#  'CCL',
#  'CCTYQ',
#  'CDNS',
#  'CE',
#  'CEG',
#  'CELG',
#  'CEPH',
#  'CERN',
#  'CF',
#  'CFC',
#  'CFG',
#  'CFN',
#  'CGP',
#  'CHD',
#  'CHIR',
#  'CHK',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CIEN',
#  'CIN',
#  'CINF',
#  'CINL',
#  'CITGQ',
#  'CKL',
#  'CL',
#  'CLF',
#  'CLX',
#  'CMA',
#  'CMCSA',
#  'CMCSK',
#  'CME',
#  'CMG',
#  'CMI',
#  'CMS',
#  'CMVT',
#  'CMX',
#  'CNA',
#  'CNC',
#  'CNCEQ',
#  'CNDT',
#  'CNP',
#  'CNRG',
#  'CNW',
#  'CNX',
#  'COC',
#  'COF',
#  'COG',
#  'COL',
#  'COMS',
#  'COO',
#  'COP',
#  'COST',
#  'COTY',
#  'COV',
#  'CPB',
#  'CPGX',
#  'CPNLQ',
#  'CPRI',
#  'CPRT',
#  'CR',
#  'CRM',
#  'CSC',
#  'CSCO',
#  'CSRA',
#  'CSX',
#  'CTAS',
#  'CTB',
#  'CTL',
#  'CTSH',
#  'CTVA',
#  'CTXS',
#  'CVC',
#  'CVET',
#  'CVG',
#  'CVGYQ',
#  'CVH',
#  'CVS',
#  'CVX',
#  'CXO',
#  'D',
#  'DAL',
#  'DALRQ',
#  'DCNAQ',
#  'DD',
#  'DDS',
#  'DE',
#  'DEC',
#  'DELL',
#  'DF',
#  'DFS',
#  'DG',
#  'DGX',
#  'DHI',
#  'DHR',
#  'DIS',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DJ',
#  'DLPH',
#  'DLR',
#  'DLTR',
#  'DLX',
#  'DNB',
#  'DNR',
#  'DO',
#  'DOV',
#  'DOW',
#  'DPHIQ',
#  'DRE',
#  'DRI',
#  'DTE',
#  'DUK',
#  'DVA',
#  'DVMT',
#  'DVN',
#  'DWDP',
#  'DXC',
#  'DYNIQ',
#  'EA',
#  'EBAY',
#  'ECL',
#  'ECO',
#  'ED',
#  'EFX',
#  'EHC',
#  'EIX',
#  'EKDKQ',
#  'EL',
#  'EMC',
#  'EMN',
#  'EMR',
#  'ENDP',
#  'ENRNQ',
#  'EOG',
#  'EOP',
#  'EP',
#  'EQIX',
#  'EQR',
#  'EQT',
#  'ES',
#  'ESRX',
#  'ESS',
#  'ESV',
#  'ETFC',
#  'ETN',
#  'ETR',
#  'ETS',
#  'EVHC',
#  'EVRG',
#  'EW',
#  'EXC',
#  'EXPD',
#  'EXPE',
#  'EXR',
#  'F',
#  'FANG',
#  'FAST',
#  'FB',
#  'FBF',
#  'FBHS',
#  'FBO',
#  'FCPT',
#  'FCX',
#  'FDO',
#  'FDX',
#  'FE',
#  'FFB',
#  'FFIV',
#  'FHN',
#  'FII',
#  'FIS',
#  'FISV',
#  'FITB',
#  'FJ',
#  'FJCC',
#  'FL',
#  'FLIR',
#  'FLMIQ',
#  'FLR',
#  'FLS',
#  'FLT',
#  'FLTWQ',
#  'FMC',
#  'FMCC',
#  'FNMA',
#  'FOSL',
#  'FOX',
#  'FOXA',
#  'FPC',
#  'FRC',
#  'FRT',
#  'FRX',
#  'FSH',
#  'FSL/B',
#  'FSLR',
#  'FTI',
#  'FTLAQ',
#  'FTNT',
#  'FTR',
#  'FTV',
#  'FWLT',
#  'GAPTQ',
#  'GAS',
#  'GBLXQ',
#  'GCO',
#  'GD',
#  'GDT',
#  'GDW',
#  'GE',
#  'GENZ',
#  'GFS/A',
#  'GGP',
#  'GHC',
#  'GIDL',
#  'GILD',
#  'GIS',
#  'GLW',
#  'GM',
#  'GMCR',
#  'GME',
#  'GNW',
#  'GOOG',
#  'GOOGL',
#  'GOSHA',
#  'GP',
#  'GPC',
#  'GPN',
#  'GPS',
#  'GPUI',
#  'GQ',
#  'GR',
#  'GRA',
#  'GRMN',
#  'GS',
#  'GT',
#  'GTGOF',
#  'GTW',
#  'GTX',
#  'GWW',
#  'HAL',
#  'HAR',
#  'HAS',
#  'HBAN',
#  'HBI',
#  'HCA',
#  'HCBK',
#  'HCP',
#  'HCR',
#  'HD',
#  'HDLM',
#  'HES',
#  'HET',
#  'HFC',
#  'HFS',
#  'HIG',
#  'HII',
#  'HLT',
#  'HM',
#  'HMA',
#  'HNZ',
#  'HOG',
#  'HOLX',
#  'HON',
#  'HOT',
#  'HP',
#  'HPC',
#  'HPE',
#  'HPQ',
#  'HRB',
#  'HRL',
#  'HRS',
#  'HRZIQ',
#  'HSH',
#  'HSIC',
#  'HSP',
#  'HST',
#  'HSY',
#  'HTMXQ',
#  'HUM',
#  'IAC',
#  'IBM',
#  'ICE',
#  'IDXX',
#  'IFF',
#  'IILGV',
#  'IKN',
#  'ILMN',
#  'IMNX',
#  'INCLF',
#  'INCY',
#  'INFO',
#  'INTC',
#  'INTU',
#  'IP',
#  'IPG',
#  'IPGP',
#  'IQV',
#  'IR',
#  'IRM',
#  'ISRG',
#  'IT',
#  'ITT',
#  'ITW',
#  'IVZ',
#  'JAVA',
#  'JBGS',
#  'JBHT',
#  'JBL',
#  'JCI',
#  'JCP',
#  'JEC',
#  'JEF',
#  'JH',
#  'JHF',
#  'JKHY',
#  'JNJ',
#  'JNPR',
#  'JNS',
#  'JNY',
#  'JOSEA',
#  'JOY',
#  'JPM',
#  'JWN',
#  'JWPI',
#  'K',
#  'KATE',
#  'KBH',
#  'KDP',
#  'KEY',
#  'KEYS',
#  'KG',
#  'KHC',
#  'KIM',
#  'KLAC',
#  'KMB',
#  'KMI',
#  'KMRTQ',
#  'KMX',
#  'KO',
#  'KORS',
#  'KR',
#  'KRB',
#  'KRFT',
#  'KRI',
#  'KSE',
#  'KSS',
#  'KSU',
#  'KTB',
#  'L',
#  'LB',
#  'LDG',
#  'LDOS',
#  'LDWIF',
#  'LEG',
#  'LEHMQ',
#  'LEN',
#  'LEN/B',
#  'LH',
#  'LHX',
#  'LIN',
#  'LK',
#  'LKQ',
#  'LLL',
#  'LLTC',
#  'LLX',
#  'LLY',
#  'LM',
#  'LMT',
#  'LNC',
#  'LNT',
#  'LO',
#  'LOW',
#  'LPX',
#  'LRCX',
#  'LU',
#  'LUB',
#  'LUV',
#  'LVLT',
#  'LW',
#  'LXK',
#  'LYB',
#  'M',
#  'MA',
#  'MAA',
#  'MAC',
#  'MAR',
#  'MAS',
#  'MAT',
#  'MBI',
#  'MCAWA',
#  'MCD',
#  'MCHP',
#  'MCK',
#  'MCO',
#  'MCWEQ',
#  'MDLZ',
#  'MDP',
#  'MDR',
#  'MDT',
#  'MEDI',
#  'MEE',
#  'MEL',
#  'MER',
#  'MERQ',
#  'MET',
#  'MFE',
#  'MGM',
#  'MHK',
#  'MHS',
#  'MI',
#  'MIRKQ',
#  'MJN',
#  'MJN-W',
#  'MKC',
#  'MKG',
#  'MKTX',
#  'MLM',
#  'MMC',
#  'MMM',
#  'MNK',
#  'MNST',
#  'MO',
#  'MOLX',
#  'MON',
#  'MOS',
#  'MPC',
#  'MRK',
#  'MRNKQ',
#  'MRO',
#  'MS',
#  'MSCI',
#  'MSFT',
#  'MSI',
#  'MTB',
#  'MTD',
#  'MTG',
#  'MTLQQ',
#  'MTW',
#  'MU',
#  'MUR',
#  'MWI',
#  'MWV',
#  'MWW',
#  'MXIM',
#  'MXS',
#  'MYL',
#  'MZIAQ',
#  'NAE',
#  'NAV',
#  'NAVI',
#  'NBL',
#  'NBR',
#  'NC',
#  'NCC',
#  'NCE',
#  'NCLH',
#  'NCR',
#  'NDAQ',
#  'NE',
#  'NEC',
#  'NEE',
#  'NEM',
#  'NEU',
#  'NFB',
#  'NFLX',
#  'NFX',
#  'NGH',
#  'NGVT',
#  'NI',
#  'NKE',
#  'NKTR',
#  'NL',
#  'NLSN',
#  'NMK',
#  'NOC',
#  'NOV',
#  'NOVL',
#  'NRG',
#  'NRTLQ',
#  'NSC',
#  'NTAP',
#  'NTRS',
#  'NUE',
#  'NVDA',
#  'NVT',
#  'NWL',
#  'NWS',
#  'NWSA',
#  'NXTL',
#  'NYT',
#  'NYX',
#  'O',
#  'OAT',
#  'ODP',
#  'OI',
#  'OK',
#  'OKE',
#  'OM',
#  'OMC',
#  'OMX',
#  'ORCL',
#  'ORLY',
#  'ORX',
#  'OWENQ',
#  'OXY',
#  'PALM',
#  'PAS',
#  'PAYX',
#  'PBCT',
#  'PBG',
#  'PBI',
#  'PCAR',
#  'PCG',
#  'PCH',
#  'PCL',
#  'PCP',
#  'PD',
#  'PDCO',
#  'PDG',
#  'PEG',
#  'PEP',
#  'PET',
#  'PETM',
#  'PFE',
#  'PFG',
#  'PG',
#  'PGL',
#  'PGR',
#  'PH',
#  'PHM',
#  'PKG',
#  'PKI',
#  'PLD',
#  'PLL',
#  'PM',
#  'PMCS',
#  'PNC',
#  'PNR',
#  'PNW',
#  'POM',
#  'PPG',
#  'PPL',
#  'PPW',
#  'PRDCQ',
#  'PRGO',
#  'PRU',
#  'PSA',
#  'PSX',
#  'PTC',
#  'PTV',
#  'PVH',
#  'PVN',
#  'PVT',
#  'PWER',
#  'PWR',
#  'PX',
#  'PXD',
#  'PYPL',
#  'QCOM',
#  'QCP',
#  'QEP',
#  'QLGC',
#  'QRVO',
#  'QTRN',
#  'R',
#  'RAD',
#  'RAI',
#  'RAL',
#  'RATL',
#  'RBD',
#  'RBK',
#  'RCL',
#  'RDC',
#  'RDPL',
#  'RE',
#  'REG',
#  'REGN',
#  'REZI',
#  'RF',
#  'RHDCQ',
#  'RHI',
#  'RHT',
#  'RIG',
#  'RJF',
#  'RL',
#  'RMD',
#  'RML',
#  'RNB',
#  'ROH',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RRC',
#  'RRD',
#  'RSG',
#  'RSHCQ',
#  'RTN',
#  'RTN/B',
#  'RX',
#  'RYAN',
#  'RYC',
#  'SANM',
#  'SAPE',
#  ...]

# %%
data.columns = a_list
data
# Out:
#            Date  0111145D  0202445Q  0203524D  0226226D  0376152D  0440296D  \
# 0    1993-09-07   13.2719   13.6829    8.4429    8.1042    11.000   57.3245
# 1    1993-09-08   13.3263   13.5315    8.2147    7.9590    11.000   57.2096
# 2    1993-09-09   13.7070   13.3800    8.7852    8.0627    11.125   59.1625
# 3    1993-09-10   13.3807   13.4810    9.4127    8.0368    11.125   59.6220
# 4    1993-09-11   13.3807   13.4810    9.4127    8.0368    11.125   59.6220
# ...         ...       ...       ...       ...       ...       ...       ...
# 9454 2019-07-27       NaN       NaN       NaN       NaN       NaN       NaN
# 9455 2019-07-28       NaN       NaN       NaN       NaN       NaN       NaN
# 9456 2019-07-29       NaN       NaN       NaN       NaN       NaN       NaN
# 9457 2019-07-30       NaN       NaN       NaN       NaN       NaN       NaN
# 9458 2019-07-31       NaN       NaN       NaN       NaN       NaN       NaN
#
#       0544749D  0574018D  0598884D  ...  YNR         YRCW     YUM   YUMC  \
# 0      17.8887    6.8315   28.1246  ...  NaN  144439.5121     NaN    NaN
# 1      17.8064    6.8315   27.5051  ...  NaN  143691.1208     NaN    NaN
# 2      17.6831    6.8315   27.7529  ...  NaN  143691.1208     NaN    NaN
# 3      17.6420    6.8773   27.5051  ...  NaN  145187.9033     NaN    NaN
# 4      17.6420    6.8773   27.5051  ...  NaN  145187.9033     NaN    NaN
# ...        ...       ...       ...  ...  ...          ...     ...    ...
# 9454       NaN       NaN       NaN  ...  NaN       3.3500  114.02  45.31
# 9455       NaN       NaN       NaN  ...  NaN       3.3500  114.02  45.31
# 9456       NaN       NaN       NaN  ...  NaN       3.1800  114.10  45.43
# 9457       NaN       NaN       NaN  ...  NaN       3.1800  113.24  44.00
# 9458       NaN       NaN       NaN  ...  NaN       3.1800  113.24  44.00
#
#          ZBH  ZETHQ     ZION      ZRN     ZTS  ZTS-W
# 0        NaN  6.875   7.1675  30.7970     NaN    NaN
# 1        NaN  6.750   6.9766  30.0188     NaN    NaN
# 2        NaN  6.625   6.9554  30.0188     NaN    NaN
# 3        NaN  6.750   7.2099  29.6852     NaN    NaN
# 4        NaN  6.750   7.2099  29.6852     NaN    NaN
# ...      ...    ...      ...      ...     ...    ...
# 9454  134.50    NaN  45.1600      NaN  115.11    NaN
# 9455  134.50    NaN  45.1600      NaN  115.11    NaN
# 9456  134.53    NaN  44.6500      NaN  115.55    NaN
# 9457  136.67    NaN  45.4800      NaN  115.79    NaN
# 9458  136.67    NaN  45.4800      NaN  115.79    NaN
#
# [9459 rows x 1200 columns]

# %%
plt.plot(data['YRCW'])

# %%
df = data
df = df.dropna(axis=1, how='any')

# %%
df.describe()
# Out:
#                 AA         AAPL         ABMD          ABT         ADBE  \
# count  9459.000000  9459.000000  9459.000000  9459.000000  9459.000000
# mean     37.738697    39.960070    42.262008    22.209420    47.648056
# std      17.757320    55.492022    80.441058    16.687665    60.738639
# min      10.776000     0.408100     2.125000     3.203700     2.006400
# 25%      22.443250     1.235950     7.313000    11.922300    13.004900
# 50%      32.538000     9.346500    12.740000    16.565800    29.790000
# 75%      53.887700    67.826500    23.425000    29.759200    43.745000
# max      92.112700   229.392100   449.750000    88.740000   311.270000
#
#                ADI          ADM          ADP         ADSK          AEP  ...  \
# count  9459.000000  9459.000000  9459.000000  9459.000000  9459.000000  ...
# mean     32.660868    21.586809    40.889298    35.345257    28.942039  ...
# std      24.411225    12.867943    34.876162    35.976634    18.610175  ...
# min       2.348200     5.457300     6.071100     4.132000     8.206200  ...
# 25%      16.102100     9.356800    21.115600     8.667500    15.881200  ...
# 50%      26.789400    20.802900    27.929300    28.800000    21.443700  ...
# 75%      42.458300    31.334350    46.502900    44.175000    35.274500  ...
# max     124.640000    50.545500   169.610000   178.210000    91.760000  ...
#
#                 WY            X          XEL           XL        XLNX  \
# count  9459.000000  9459.000000  9459.000000  9459.000000  9459.00000
# mean     16.624939    31.530904    18.013454    34.312733    28.45954
# std       7.802130    23.415861    12.637752    15.823420    22.18081
# min       5.429500     6.490000     2.846700     2.143900     1.80580
# 25%      10.519550    18.950300     9.395750    19.365500    15.19400
# 50%      14.378000    23.956700    12.850500    34.309300    21.70750
# 75%      22.547800    35.257450    22.972400    49.283150    38.23640
# max      37.981800   174.265900    61.930000    63.386200   139.26320
#
#                XOM         XRAY          XRX           YRCW         ZION
# count  9459.000000  9459.000000  9459.000000    9459.000000  9459.000000
# mean     45.357700    27.510228    32.874184  106369.946519    34.278650
# std      25.251079    17.588921    21.038429  112806.538215    17.359362
# min       7.208900     4.093600     8.597800       2.660000     5.892600
# 25%      23.208300     9.285400    20.968000      18.215000    20.739500
# 50%      45.625500    26.577800    27.654300  101587.581400    32.459300
# 75%      70.704500    39.108750    33.937350  159917.470700    46.122700
# max      88.898500    68.076300   121.680000  475500.047600    77.687200
#
# [8 rows x 390 columns]

# %%
df.columns
# Out:
# Index(['Date', 'AA', 'AAPL', 'ABMD', 'ABT', 'ADBE', 'ADI', 'ADM', 'ADP',
#        'ADSK',
#        ...
#        'WY', 'X', 'XEL', 'XL', 'XLNX', 'XOM', 'XRAY', 'XRX', 'YRCW', 'ZION'],
#       dtype='object', length=391)

# %%
cols = []
for i in df.columns:
  cols.append(i)

# %%
cols.remove('Date')

# %%
a = 0
for i in cols:
  a = df.at[0,i]
  for j in range(1,9459):
    df.at[j,i] = df.at[j,i]/a
df.head()
# Out:
#         Date         AA      AAPL      ABMD       ABT      ADBE       ADI  \
# 0 1993-09-07  13.628500  0.804400  3.750000  3.265900  2.371200  2.960800
# 1 1993-09-08   0.981164  1.019020  1.166667  0.980955  1.025641  0.980309
# 2 1993-09-09   0.988018  0.990428  1.166667  1.000000  0.974359  1.014793
# 3 1993-09-10   0.982881  1.000000  1.100000  1.000000  1.000000  1.049277
# 4 1993-09-11   0.982881  1.000000  1.100000  1.000000  1.000000  1.049277
#
#         ADM       ADP      ADSK  ...        WY          X       XEL  \
# 0  6.843800  6.102400  5.352500  ...  6.780300  20.543400  6.969600
# 1  0.994711  0.997444  0.989239  ...  0.981063   0.992187  1.000000
# 2  0.989421  0.994871  0.991929  ...  0.971609   0.996096  0.994691
# 3  0.994711  1.007718  1.016123  ...  0.987375   1.007813  1.005294
# 4  0.994711  1.007718  1.016123  ...  0.987375   1.007813  1.005294
#
#           XL      XLNX       XOM      XRAY        XRX           YRCW      ZION
# 0  12.314900  2.534200  8.019800  5.303600  20.550300  144439.512100  7.167500
# 1   0.994779  0.976048  1.007693  0.966212   1.000000       0.994819  0.973366
# 2   0.994779  1.017954  0.998080  0.966212   0.988015       0.994819  0.970408
# 3   0.994779  1.068858  1.009614  1.000000   0.993153       1.005181  1.005916
# 4   0.994779  1.068858  1.009614  1.000000   0.993153       1.005181  1.005916
#
# [5 rows x 391 columns]

# %%
for i in cols:
  df.at[0,i] = 1

# %%
df.head()
# Out:
#         Date        AA      AAPL      ABMD       ABT      ADBE       ADI  \
# 0 1993-09-07  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1 1993-09-08  0.981164  1.019020  1.166667  0.980955  1.025641  0.980309
# 2 1993-09-09  0.988018  0.990428  1.166667  1.000000  0.974359  1.014793
# 3 1993-09-10  0.982881  1.000000  1.100000  1.000000  1.000000  1.049277
# 4 1993-09-11  0.982881  1.000000  1.100000  1.000000  1.000000  1.049277
#
#         ADM       ADP      ADSK  ...        WY         X       XEL        XL  \
# 0  1.000000  1.000000  1.000000  ...  1.000000  1.000000  1.000000  1.000000
# 1  0.994711  0.997444  0.989239  ...  0.981063  0.992187  1.000000  0.994779
# 2  0.989421  0.994871  0.991929  ...  0.971609  0.996096  0.994691  0.994779
# 3  0.994711  1.007718  1.016123  ...  0.987375  1.007813  1.005294  0.994779
# 4  0.994711  1.007718  1.016123  ...  0.987375  1.007813  1.005294  0.994779
#
#        XLNX       XOM      XRAY       XRX      YRCW      ZION
# 0  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  0.976048  1.007693  0.966212  1.000000  0.994819  0.973366
# 2  1.017954  0.998080  0.966212  0.988015  0.994819  0.970408
# 3  1.068858  1.009614  1.000000  0.993153  1.005181  1.005916
# 4  1.068858  1.009614  1.000000  0.993153  1.005181  1.005916
#
# [5 rows x 391 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
# <ipython-input-227-e0d9d975d684>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
#            Date        AA        AAPL       ABMD        ABT        ADBE  \
# 0    1993-09-07  1.000000    1.000000   1.000000   1.000000    1.000000
# 1    1993-09-08  0.981164    1.019020   1.166667   0.980955    1.025641
# 2    1993-09-09  0.988018    0.990428   1.166667   1.000000    0.974359
# 3    1993-09-10  0.982881    1.000000   1.100000   1.000000    1.000000
# 4    1993-09-11  0.982881    1.000000   1.100000   1.000000    1.000000
# ...         ...       ...         ...        ...        ...         ...
# 9454 2019-07-27  1.697179  258.254600  72.709333  26.868551  131.271086
# 9455 2019-07-28  1.697179  258.254600  72.709333  26.868551  131.271086
# 9456 2019-07-29  1.696445  260.666335  73.581333  27.113506  129.563090
# 9457 2019-07-30  1.690575  259.547489  74.461333  27.040020  128.053306
# 9458 2019-07-31  1.690575  259.547489  74.461333  27.040020  128.053306
#
#             ADI       ADM        ADP       ADSK  ...        WY         X  \
# 0      1.000000  1.000000   1.000000   1.000000  ...  1.000000  1.000000
# 1      0.980309  0.994711   0.997444   0.989239  ...  0.981063  0.992187
# 2      1.014793  0.989421   0.994871   0.991929  ...  0.971609  0.996096
# 3      1.049277  0.994711   1.007718   1.016123  ...  0.987375  1.007813
# 4      1.049277  0.994711   1.007718   1.016123  ...  0.987375  1.007813
# ...         ...       ...        ...        ...  ...       ...       ...
# 9454  41.137530  5.930916  27.738267  31.385334  ...  3.865611  0.739410
# 9455  41.137530  5.930916  27.738267  31.385334  ...  3.865611  0.739410
# 9456  40.938260  5.976212  27.515404  30.410089  ...  3.811041  0.743304
# 9457  40.853823  5.983518  27.038542  29.946754  ...  3.847912  0.764722
# 9458  40.853823  5.983518  27.038542  29.946754  ...  3.847912  0.764722
#
#            XEL        XL       XLNX       XOM       XRAY       XRX      YRCW  \
# 0     1.000000  1.000000   1.000000  1.000000   1.000000  1.000000  1.000000
# 1     1.000000  0.994779   0.976048  1.007693   0.966212  1.000000  0.994819
# 2     0.994691  0.994779   1.017954  0.998080   0.966212  0.988015  0.994819
# 3     1.005294  0.994779   1.068858  1.009614   1.000000  0.993153  1.005181
# 4     1.005294  0.994779   1.068858  1.009614   1.000000  0.993153  1.005181
# ...        ...       ...        ...       ...        ...       ...       ...
# 9454  8.681990  4.676449  47.656065  9.328163  10.562637  1.675401  0.000023
# 9455  8.681990  4.676449  47.656065  9.328163  10.562637  1.675401  0.000023
# 9456  8.749426  4.676449  47.569253  9.394249  10.628630  1.651557  0.000022
# 9457  8.693469  4.676449  47.158867  9.395496  10.685195  1.595111  0.000022
# 9458  8.693469  4.676449  47.158867  9.395496  10.685195  1.595111  0.000022
#
#           ZION
# 0     1.000000
# 1     0.973366
# 2     0.970408
# 3     1.005916
# 4     1.005916
# ...        ...
# 9454  6.300663
# 9455  6.300663
# 9456  6.229508
# 9457  6.345309
# 9458  6.345309
#
# [9459 rows x 391 columns]

# %%
cols.insert(0, 'Date')
cols
# Out:
# ['Date',
#  'AA',
#  'AAPL',
#  'ABMD',
#  'ABT',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'AEP',
#  'AES',
#  'AFL',
#  'AGN',
#  'AIG',
#  'AJG',
#  'ALK',
#  'ALL',
#  'AMAT',
#  'AMD',
#  'AMGN',
#  'AN',
#  'ANDV',
#  'AON',
#  'AOS',
#  'APA',
#  'APC',
#  'APD',
#  'ASH',
#  'ATGE',
#  'AVP',
#  'AVY',
#  'AXP',
#  'AZO',
#  'BA',
#  'BAC',
#  'BAX',
#  'BBBY',
#  'BBT',
#  'BBY',
#  'BC',
#  'BCO',
#  'BDX',
#  'BEN',
#  'BF/B',
#  'BGG',
#  'BHGE',
#  'BIG',
#  'BIIB',
#  'BK',
#  'BLL',
#  'BMS',
#  'BMY',
#  'BSET',
#  'BSX',
#  'BWA',
#  'C',
#  'CA',
#  'CAG',
#  'CAH',
#  'CAL',
#  'CAR',
#  'CAT',
#  'CB',
#  'CBS',
#  'CCK',
#  'CCL',
#  'CDNS',
#  'CELG',
#  'CERN',
#  'CHD',
#  'CHK',
#  'CI',
#  'CINF',
#  'CL',
#  'CLF',
#  'CLX',
#  'CMA',
#  'CMCSA',
#  'CMI',
#  'CMS',
#  'CNA',
#  'CNP',
#  'COG',
#  'COO',
#  'COP',
#  'COST',
#  'CPB',
#  'CR',
#  'CSCO',
#  'CSX',
#  'CTAS',
#  'CTB',
#  'CTL',
#  'CVS',
#  'CVX',
#  'D',
#  'DD',
#  'DDS',
#  'DE',
#  'DHI',
#  'DHR',
#  'DIS',
#  'DLX',
#  'DOV',
#  'DRE',
#  'DTE',
#  'DUK',
#  'DVN',
#  'EA',
#  'ECL',
#  'ED',
#  'EFX',
#  'EHC',
#  'EIX',
#  'EMR',
#  'EOG',
#  'EQR',
#  'EQT',
#  'ES',
#  'ESRX',
#  'ESV',
#  'ETN',
#  'ETR',
#  'EVRG',
#  'EXC',
#  'EXPD',
#  'F',
#  'FAST',
#  'FDX',
#  'FHN',
#  'FISV',
#  'FITB',
#  'FL',
#  'FLIR',
#  'FLS',
#  'FMC',
#  'FMCC',
#  'FNMA',
#  'FOSL',
#  'FRT',
#  'FTR',
#  'GCO',
#  'GD',
#  'GE',
#  'GGP',
#  'GHC',
#  'GILD',
#  'GIS',
#  'GLW',
#  'GPC',
#  'GPS',
#  'GT',
#  'GWW',
#  'HAL',
#  'HAS',
#  'HBAN',
#  'HCP',
#  'HD',
#  'HES',
#  'HFC',
#  'HOG',
#  'HOLX',
#  'HON',
#  'HP',
#  'HPQ',
#  'HRB',
#  'HRL',
#  'HST',
#  'HSY',
#  'HUM',
#  'IAC',
#  'IBM',
#  'IDXX',
#  'IFF',
#  'INTC',
#  'INTU',
#  'IP',
#  'IPG',
#  'IR',
#  'ITT',
#  'ITW',
#  'JBHT',
#  'JBL',
#  'JCI',
#  'JCP',
#  'JEC',
#  'JEF',
#  'JNJ',
#  'JPM',
#  'JWN',
#  'K',
#  'KBH',
#  'KEY',
#  'KIM',
#  'KLAC',
#  'KMB',
#  'KO',
#  'KR',
#  'KSS',
#  'KSU',
#  'L',
#  'LB',
#  'LEG',
#  'LEN',
#  'LLY',
#  'LM',
#  'LNC',
#  'LNT',
#  'LOW',
#  'LPX',
#  'LRCX',
#  'LUB',
#  'LUV',
#  'M',
#  'MAS',
#  'MAT',
#  'MBI',
#  'MCD',
#  'MCHP',
#  'MDP',
#  'MDR',
#  'MDT',
#  'MGM',
#  'MHK',
#  'MKC',
#  'MMC',
#  'MMM',
#  'MNST',
#  'MO',
#  'MOS',
#  'MRK',
#  'MRO',
#  'MS',
#  'MSFT',
#  'MSI',
#  'MTB',
#  'MTG',
#  'MTW',
#  'MU',
#  'MUR',
#  'MXIM',
#  'MYL',
#  'NAV',
#  'NBL',
#  'NBR',
#  'NC',
#  'NE',
#  'NEE',
#  'NEM',
#  'NEU',
#  'NI',
#  'NKE',
#  'NL',
#  'NOC',
#  'NSC',
#  'NTRS',
#  'NUE',
#  'NWL',
#  'NYT',
#  'ODP',
#  'OI',
#  'OKE',
#  'OMC',
#  'ORCL',
#  'ORLY',
#  'OXY',
#  'PAYX',
#  'PBCT',
#  'PBI',
#  'PCAR',
#  'PCG',
#  'PCH',
#  'PDCO',
#  'PEG',
#  'PEP',
#  'PFE',
#  'PG',
#  'PGR',
#  'PH',
#  'PHM',
#  'PKI',
#  'PNC',
#  'PNR',
#  'PNW',
#  'PPG',
#  'PPL',
#  'PRGO',
#  'PSA',
#  'PTC',
#  'PVH',
#  'PX',
#  'QCOM',
#  'R',
#  'RAD',
#  'RCL',
#  'RDC',
#  'REGN',
#  'RF',
#  'RHI',
#  'RIG',
#  'RJF',
#  'ROP',
#  'ROST',
#  'RRC',
#  'RRD',
#  'RTN',
#  'SANM',
#  'SBUX',
#  'SCG',
#  'SCHW',
#  'SCI',
#  'SHW',
#  'SIG',
#  'SIVB',
#  'SJM',
#  'SKY',
#  'SLB',
#  'SLM',
#  'SNA',
#  'SNPS',
#  'SNV',
#  'SO',
#  'SPGI',
#  'SPXC',
#  'SSP',
#  'STI',
#  'STT',
#  'STZ',
#  'SVU',
#  'SWK',
#  'SWKS',
#  'SWN',
#  'SYK',
#  'SYMC',
#  'SYY',
#  'T',
#  'TAP',
#  'TER',
#  'TEX',
#  'TGNA',
#  'TGT',
#  'THC',
#  'TIF',
#  'TJX',
#  'TKR',
#  'TMK',
#  'TMO',
#  'TROW',
#  'TRV',
#  'TSN',
#  'TSS',
#  'TXN',
#  'TXT',
#  'UDR',
#  'UHS',
#  'UIS',
#  'UN',
#  'UNH',
#  'UNM',
#  'UNP',
#  'USB',
#  'UTX',
#  'VAR',
#  'VFC',
#  'VMC',
#  'VNO',
#  'VRTX',
#  'VTR',
#  'VVI',
#  'VZ',
#  'WBA',
#  'WDC',
#  'WEC',
#  'WELL',
#  'WFC',
#  'WHR',
#  'WM',
#  'WMB',
#  'WMT',
#  'WOR',
#  'WY',
#  'X',
#  'XEL',
#  'XL',
#  'XLNX',
#  'XOM',
#  'XRAY',
#  'XRX',
#  'YRCW',
#  'ZION']

# %%
df.head()
stocks=df
stocks
# Out:
#            Date        AA        AAPL       ABMD        ABT        ADBE  \
# 0    1993-09-07  1.000000    1.000000   1.000000   1.000000    1.000000
# 1    1993-09-08  0.981164    1.019020   1.166667   0.980955    1.025641
# 2    1993-09-09  0.988018    0.990428   1.166667   1.000000    0.974359
# 3    1993-09-10  0.982881    1.000000   1.100000   1.000000    1.000000
# 4    1993-09-11  0.982881    1.000000   1.100000   1.000000    1.000000
# ...         ...       ...         ...        ...        ...         ...
# 9454 2019-07-27  1.697179  258.254600  72.709333  26.868551  131.271086
# 9455 2019-07-28  1.697179  258.254600  72.709333  26.868551  131.271086
# 9456 2019-07-29  1.696445  260.666335  73.581333  27.113506  129.563090
# 9457 2019-07-30  1.690575  259.547489  74.461333  27.040020  128.053306
# 9458 2019-07-31  1.690575  259.547489  74.461333  27.040020  128.053306
#
#             ADI       ADM        ADP       ADSK  ...        WY         X  \
# 0      1.000000  1.000000   1.000000   1.000000  ...  1.000000  1.000000
# 1      0.980309  0.994711   0.997444   0.989239  ...  0.981063  0.992187
# 2      1.014793  0.989421   0.994871   0.991929  ...  0.971609  0.996096
# 3      1.049277  0.994711   1.007718   1.016123  ...  0.987375  1.007813
# 4      1.049277  0.994711   1.007718   1.016123  ...  0.987375  1.007813
# ...         ...       ...        ...        ...  ...       ...       ...
# 9454  41.137530  5.930916  27.738267  31.385334  ...  3.865611  0.739410
# 9455  41.137530  5.930916  27.738267  31.385334  ...  3.865611  0.739410
# 9456  40.938260  5.976212  27.515404  30.410089  ...  3.811041  0.743304
# 9457  40.853823  5.983518  27.038542  29.946754  ...  3.847912  0.764722
# 9458  40.853823  5.983518  27.038542  29.946754  ...  3.847912  0.764722
#
#            XEL        XL       XLNX       XOM       XRAY       XRX      YRCW  \
# 0     1.000000  1.000000   1.000000  1.000000   1.000000  1.000000  1.000000
# 1     1.000000  0.994779   0.976048  1.007693   0.966212  1.000000  0.994819
# 2     0.994691  0.994779   1.017954  0.998080   0.966212  0.988015  0.994819
# 3     1.005294  0.994779   1.068858  1.009614   1.000000  0.993153  1.005181
# 4     1.005294  0.994779   1.068858  1.009614   1.000000  0.993153  1.005181
# ...        ...       ...        ...       ...        ...       ...       ...
# 9454  8.681990  4.676449  47.656065  9.328163  10.562637  1.675401  0.000023
# 9455  8.681990  4.676449  47.656065  9.328163  10.562637  1.675401  0.000023
# 9456  8.749426  4.676449  47.569253  9.394249  10.628630  1.651557  0.000022
# 9457  8.693469  4.676449  47.158867  9.395496  10.685195  1.595111  0.000022
# 9458  8.693469  4.676449  47.158867  9.395496  10.685195  1.595111  0.000022
#
#           ZION
# 0     1.000000
# 1     0.973366
# 2     0.970408
# 3     1.005916
# 4     1.005916
# ...        ...
# 9454  6.300663
# 9455  6.300663
# 9456  6.229508
# 9457  6.345309
# 9458  6.345309
#
# [9459 rows x 391 columns]

# %% [markdown]
# # Stocks EDA by Stephanie

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import mean
from numpy import std
import scipy
import datetime
from scipy.optimize import minimize
# %matplotlib inline

# %%
start = datetime.datetime(2017,9,7)
end= datetime.datetime(2019,7,31)

# %%
stocks_short = stocks[(stocks["Date"] >= start) & (stocks["Date"] <= end)]
stocks_short.dropna(axis=1,inplace=True)
# Out:
# <ipython-input-232-5470bdc14dac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stocks_short.dropna(axis=1,inplace=True)

# %%
stocks = stocks_short.columns[1:] # column 0 has the date, so drop that
stocks_return = stocks_short.iloc[-1,1:]/stocks_short.iloc[0,1:]-1 # last/first-1
# calcuate standard variation of time series and divide by first price
stocks_vol = stocks_short.iloc[:,1:].std()/stocks_short.iloc[0,1:] 
sharpe_ratio = stocks_return/stocks_vol # return divided by variance

# %%
stocks_return
# Out:
# AA     -0.484909
# AAPL    0.318841
# ABMD     0.81495
# ABT     0.755066
# ADBE    0.953046
#           ...
# XOM     0.002137
# XRAY   -0.011361
# XRX     0.074574
# YRCW   -0.762332
# ZION    0.126292
# Length: 390, dtype: object

# %%
plt.scatter(stocks_vol,stocks_return)
plt.plot([0,1],[0,5],ls='--') # reference line of return = 5*std
plt.xlim([.0,1])
plt.ylim([-1,4])
plt.xlabel('Volatility')
plt.ylabel('Return');

# %% [markdown]
# I don't know why volatility is showing indiscrepancies

# %%
f, axs = plt.subplots(1, 3, figsize=(13,4))
axs[0].hist(stocks_return,20); # but the data in 20 bins
axs[0].set_title('Return')
axs[1].hist(stocks_vol,20);
axs[1].set_title('Volatility')
axs[2].hist(sharpe_ratio,20);
axs[2].set_title('Sharpe Ratio')
# Out:
# Text(0.5, 1.0, 'Sharpe Ratio')

# %% [markdown]
# Sorting by perfomance and printing the top 20 performing stocks

# %%
sharpe_ratio_sorted = pd.Series.sort_values(sharpe_ratio,ascending=False)
sharpe_ratio_sorted.head(20)
# Out:
# SHW     5.519857
# TXN     5.442351
# NC      4.898676
# FISV    4.785566
# CTAS    4.619336
# KLAC    4.546553
# DE      4.517103
# UHS     4.501632
# ITT     4.431521
# TMK     4.415192
# SYK     4.400612
# AXP     4.399678
# HAS     4.390518
# TER     4.380748
# JPM     4.379184
# AJG     4.324892
# TSS     4.245137
# APD     4.212989
# ROST    4.199651
# SPGI    4.186071
# dtype: object

# %% [markdown]
# Note that the list is different from the unfiltered one.
#
# I created a random portfolio of NSTOCKS stocks that have a positive return for the period of interest. The list is also different from the unfiltered one

# %%
NSTOCKS = 20
# drop all the stocks with negative return and take a random sample of the remainder
stocks_return = stocks_return[stocks_return > 0].sample(n=NSTOCKS, random_state=1)
stocks_return
# Out:
# ATGE    0.425619
# AVY     0.275235
# OKE     0.270835
# CB      0.166689
# HP      0.133587
# PHM     0.282374
# D       0.003149
# SYK     0.523865
# DOV     0.435078
# VRTX    0.063547
# LUV     0.016498
# XEL     0.264679
# MCHP    0.134065
# RHI      0.39561
# AEP     0.256876
# EMR     0.158178
# ASH     0.327909
# JCI      0.08989
# UN      0.011696
# AMGN    0.011987
# dtype: object

# %%
 # create a new dataframe with the first column being the dates
portfolio = pd.DataFrame(stocks_short['Date'],columns=['Date'])
for col in stocks_short.columns: # go through all the columns in our original data frame
    if col in stocks_return.index: # check if this column is in the names for our random sample
        portfolio = pd.concat([portfolio,stocks_short[col]],axis=1) # if so, add the stock prices to the new dataframe

# %%
# diff calculates the daily return, then we calculate the correlation between variables
corrs = portfolio.diff(axis=0, periods=1).corr() 
mask = np.triu(np.ones_like(corrs, dtype=np.bool)) # create a mask to only show entries below the main diagonal
f, ax = plt.subplots(figsize=(10, 8))
# plot the heatmap with a colour bar
sns.heatmap(corrs, mask=mask, center=0, annot=True, square=True, linewidths=.5) 
# adjust the top and bottom, so that we can see the whole figure
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# <ipython-input-240-69efa9103861>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(corrs, dtype=np.bool)) # create a mask to only show entries below the main diagonal
# (20.5, -0.5)

# %% [markdown]
# The higher the number of samples the more concentrated the scatter plot is.

# %%
NSAMP = 200 # set the number of random samples of the weights
result_array = np.zeros((2, NSAMP)) # create a numpy array to store the returns and risk for each sample
Ro = portfolio.iloc[0,1:] # store the initial stock prices
R = portfolio.iloc[-1,1:] # store the final stock prices
for i in range(NSAMP): # loop over all the samples
    w = np.random.rand(NSTOCKS) # generates weights in the range [0,1] for all the stockes
    # calculate the initial value of the stock portfolio, @ => multiply two matrices, .T => transpose of matrix
    Po = w.T @ Ro
    w = w/Po # normalize random numbers so that portfolio has an initial value of 1
    Pf = w.T @ R # calculate final value of portfolio
    risk = np.sqrt(w.T @ corrs @ w) # use the formula above to calculate the risk
    result_array[:,i] = [risk,Pf-1] # store risk and return
# plot risk vs returns and add axis labels
plt.scatter(result_array[0,:],result_array[1,:]) 
plt.xlabel('Risk')
plt.ylabel('Return')
# Out:
# Text(0, 0.5, 'Return')

# %%
NSAMP = 2000 # set the number of random samples of the weights
result_array = np.zeros((2, NSAMP)) # create a numpy array to store the returns and risk for each sample
Ro = portfolio.iloc[0,1:] # store the initial stock prices
R = portfolio.iloc[-1,1:] # store the final stock prices
for i in range(NSAMP): # loop over all the samples
    w = np.random.rand(NSTOCKS) # generates weights in the range [0,1] for all the stockes
    # calculate the initial value of the stock portfolio, @ => multiply two matrices, .T => transpose of matrix
    Po = w.T @ Ro
    w = w/Po # normalize random numbers so that portfolio has an initial value of 1
    Pf = w.T @ R # calculate final value of portfolio
    risk = np.sqrt(w.T @ corrs @ w) # use the formula above to calculate the risk
    result_array[:,i] = [risk,Pf-1] # store risk and return
# plot risk vs returns and add axis labels
plt.scatter(result_array[0,:],result_array[1,:]) 
plt.xlabel('Risk')
plt.ylabel('Return')
# Out:
# Text(0, 0.5, 'Return')

# %% [markdown]
# ## Sharpe ratio
# (continued)

# %%
# Importing required modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')
# %matplotlib inline
stocks
# Out:
# Index(['AA', 'AAPL', 'ABMD', 'ABT', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEP',
#        ...
#        'WY', 'X', 'XEL', 'XL', 'XLNX', 'XOM', 'XRAY', 'XRX', 'YRCW', 'ZION'],
#       dtype='object', length=390)

# %%
portfolio.head()
# Out:
#            Date       AEP       AMGN        ASH       ATGE        AVY  \
# 8766 2017-09-07  6.430158  43.776048  11.001726  11.034726  13.291799
# 8767 2017-09-08  6.461513  43.758976  11.064518  10.777731  13.366380
# 8768 2017-09-09  6.461513  43.758976  11.064518  10.777731  13.366380
# 8769 2017-09-10  6.461513  43.758976  11.064518  10.777731  13.366380
# 8770 2017-09-11  6.492867  45.175998  11.405402  10.841980  13.508388
#
#              CB          D        DOV       EMR  ...        JCI       LUV  \
# 8766  18.694836  10.014796  11.773530  7.657924  ...  12.866531  8.286385
# 8767  19.522265  10.141503  11.909954  7.682097  ...  12.850119  8.391133
# 8768  19.522265  10.141503  11.909954  7.682097  ...  12.850119  8.391133
# 8769  19.522265  10.141503  11.909954  7.682097  ...  12.850119  8.391133
# 8770  20.219519  10.228536  11.997273  7.746959  ...  12.928882  8.506989
#
#            MCHP        OKE       PHM        RHI        SYK         UN    VRTX  \
# 8766  61.303276  31.792305  6.637243  24.766187  46.028929  13.899478  31.882
# 8767  60.728048  31.651578  6.726017  25.119560  46.119557  13.931653  31.766
# 8768  60.728048  31.651578  6.726017  25.119560  46.119557  13.931653  31.766
# 8769  60.728048  31.651578  6.726017  25.119560  46.119557  13.931653  31.766
# 8770  61.997778  31.820439  6.833086  25.323906  46.504696  13.977617  31.562
#
#            XEL
# 8766  6.874053
# 8767  6.920899
# 8768  6.920899
# 8769  6.920899
# 8770  6.959467
#
# [5 rows x 21 columns]

# %% [markdown]
# I was trying to make a time series graph for the top 20 stocks at a given time. However, the stock list changes everytime I run all the codes of the notebook. I made sure that the code did not randomise the the stock picks each time, but that doesnt seem to work.

# %%
portfolio.plot(x='Date',y=['AN','ANDV','ATGE','BBT','BDX','CAT','CNP','CR','DE','EQR','FISV','IBM','ITT','LOW','MRO','PH','SHW','SVU','T','THC'])
plt.xlabel('Date')         
plt.ylabel('The stock')
plt.xticks(rotation=45);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-246-30608c34809f> in <module>
# ----> 1 portfolio.plot(x='Date',y=['AN','ANDV','ATGE','BBT','BDX','CAT','CNP','CR','DE','EQR','FISV','IBM','ITT','LOW','MRO','PH','SHW','SVU','T','THC'])
#       2 plt.xlabel('Date')
#       3 plt.ylabel('The stock')
#       4 plt.xticks(rotation=45);
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     939
#     940                 # don't overwrite
# --> 941                 data = data[y].copy()
#     942
#     943                 if isinstance(data, ABCSeries):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['MRO', 'CR', 'THC', 'CAT', 'AN', 'CNP', 'FISV', 'ANDV', 'SHW', 'T', 'BDX', 'ITT', 'SVU', 'DE', 'IBM', 'PH', 'EQR', 'LOW', 'BBT'] not in index"

# %%
# # The below will pull back stock prices from the start date until end date specified.
# start_sp = datetime.datetime(2010, 1, 1)
# end_sp = datetime.datetime(2019, 7, 31)

# # This variable is used for YTD performance.
# end_of_last_year = datetime.datetime(2018, 12, 29)

# # These are separate if for some reason want different date range than SP.
# stocks_start = datetime.datetime(2010, 1, 1)
# stocks_end = datetime.datetime(2019, 7, 31)

# %%
# stocks.plot(x='Date',y=['AAPL','ADBE','ABT','NC','FISV','CTAS','SHW'])
# plt.xlabel('Date')         
# plt.ylabel('The stock')
# plt.xticks(rotation=45);

# %%
# stocks_diff = stocks.diff
# stocks_diff

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
# from matplotlib import style

# # Adjusting the size of matplotlib
# import matplotlib as mpl
# mpl.rc('figure', figsize=(8, 7))
# mpl.__version__

# # Adjusting the style of matplotlib
# style.use('ggplot')

# stocks.plot(label='AAPL')
# stocks.plot(label='ADBE')
# plt.legend()

# %%
portfolio.plot()

# %%
# start = datetime.datetime(2017,9,7)
# end= datetime.datetime(2019,7,31)
# morning_data_three_sites = stocks.loc[start:end, ["SHW", "TXN", "NC"]]
# # Plots each column as a different line, over the time range in the filtered dataframe.
# morning_data_three_sites.plot.line();

# %%
# plt.figure(figsize=(12, 10))
# plt.scatter(rets.mean(), rets.std(), area)
# plt.xlabel('Expected return')
# plt.ylabel('Risk')

# for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
#     plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom',arrowprops=dict(
#     arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))

# %%
sns.jointplot('SHW', 'TXN', stocks, kind='scatter', color='seagreen')

# %%
# sns.pairplot(stocks,kind='reg')

# %%
plt.figure(figsize=(12, 8))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
plt.subplot(2, 2, i)
company[‘Volume’].plot()
plt.ylabel(‘Volume’)
# plt.xlabel(None)
plt.title(f”{tech_list[i — 1]}”)

# %%
# stocks["2019-05-20":"2019-05-21"].plot();

# %%
# # visualize the stock_data
# stocks.plt(subplots=True, title='Stock Data')

# # summarize the stock_data
# print(stocks.describe())
# plt.show()

# %%
# sharpe_ratio(BBT['Daily Return'])

# %%
# sharpe_ratio(AAPL['Daily Return'])

# %%
df[cols].set_index('Date').plot()

# %%
from google.colab import drive

drive.mount('/content/drive')
path = '/content/drive/Shareddrives/ADS2002 Portfolio Optimisation/Data/NoNaNs.csv'

with open(path, 'w', encoding = 'utf-8-sig') as f:
  df.to_csv(f)
